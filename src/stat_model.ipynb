# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime as dt
from scipy.spatial import distance
import scipy.stats as stats
import itertools as it

# %matplotlib inline

# %%
df = pd.read_csv(".\\_generated\\wifi_1.data", index_col = False, header = None, low_memory = False, \
                 names = ['timestamp', 'uuid', 'bssid', 'ssid', 'capabilities', \
                          'freq0', 'freq1', 'chwidth', 'freq', 'level', 'operator', \
                          'time', 'venue', '802', 'passpoint'])

# %%
df['timestamp'] = df['timestamp'].apply(lambda x: dt.strptime(x, '%d.%m.%Y_%H:%M:%S.%f'))
df.index = pd.DatetimeIndex(df.timestamp)
df = df.drop(df.columns.difference(['uuid', 'bssid']), axis = 1)
df = df.sort_index()

# %%
bssid_map = { bssid.replace(' ', ''): 0 for bssid in df.bssid.unique() }

# %%
def update_map(bssid):
    bssid_map[bssid] += 1
    return bssid

# %%
_ = df.bssid.apply(lambda bssid: update_map(bssid))

# %%
bssid_map = dict(sorted(bssid_map.items(), key=lambda item: item[1], reverse=True)[:80])

# %%
sum_of_freq = 0
for key, value in bssid_map.items():
    sum_of_freq += value
    
bssid_map = { key: value / sum_of_freq for key, value in bssid_map.items() }

# %%
bssid_map
# Out:
# {'34:ce:00:4d:64:1e': 0.04389406345484589,
#  '34:ce:00:4d:64:1d': 0.04337527347247736,
#  '40:b4:f0:28:29:c3': 0.04262570502820113,
#  '40:b4:f0:28:29:c1': 0.04262570502820113,
#  '50:d4:f7:66:35:d0': 0.040964100102465636,
#  '40:b4:f0:28:29:c2': 0.03946311698621791,
#  '40:b4:f0:28:29:c0': 0.03900709874548828,
#  'd4:6e:0e:a0:40:56': 0.03855108050475865,
#  '20:4e:7f:75:b5:36': 0.038418152110699814,
#  'b0:a8:6e:41:ec:c2': 0.027457098283931357,
#  'b0:a8:6e:41:ec:c1': 0.02696784794468702,
#  'b0:a8:6e:41:ec:c3': 0.026954924350820187,
#  '3c:8a:b0:f9:27:02': 0.026659527919578322,
#  'b0:a8:6e:41:ec:c0': 0.02661152599950152,
#  '10:0e:7e:17:02:c2': 0.02365940791477813,
#  '3c:8a:b0:f9:27:00': 0.023020613132217597,
#  '10:0e:7e:17:02:c0': 0.02122977226781379,
#  '50:64:2b:4e:08:dd': 0.019887564733358565,
#  '2c:4d:54:5b:80:28': 0.019708480646918186,
#  'b0:a8:6e:41:e4:82': 0.01921553785228332,
#  'bc:ee:7b:68:0f:4c': 0.017991488890324845,
#  '40:31:3c:28:93:ed': 0.01724007421835335,
#  'b0:a8:6e:41:e4:80': 0.016800672026881076,
#  'd8:47:32:c3:1b:90': 0.01668251345438433,
#  'c0:25:e9:92:cc:5a': 0.015318151187585964,
#  '5e:ea:1d:8b:34:df': 0.015174145427355555,
#  '2c:fd:a1:05:25:c4': 0.01456489028791921,
#  '40:b4:f0:9b:f9:00': 0.014088563542541701,
#  'ec:08:6b:c9:c4:a0': 0.013977789880826002,
#  '40:b4:f0:9b:f9:02': 0.013867016219110302,
#  'f4:f2:6d:4c:5e:ea': 0.01360854434177367,
#  '7c:8b:ca:2c:6c:a8': 0.013591928292516316,
#  'ea:d8:d1:7a:da:af': 0.01103305670688366,
#  '0c:8f:ff:81:2b:f8': 0.009292063990251918,
#  '50:ff:20:1f:55:44': 0.00916098182388834,
#  'fc:8b:97:54:97:ea': 0.008498186081289405,
#  '74:d0:2b:69:2e:54': 0.00832464067793481,
#  '30:b5:c2:3f:ab:e2': 0.0073387550886650854,
#  '10:0e:7e:17:02:c1': 0.007296291851674067,
#  '10:0e:7e:17:02:c3': 0.007137516269881564,
#  '40:b4:f0:f1:55:02': 0.00634179213322379,
#  '40:b4:f0:22:ba:82': 0.006336253450138006,
#  '40:b4:f0:f1:55:00': 0.006277174163889633,
#  '40:b4:f0:22:ba:80': 0.005715920944530089,
#  '40:b4:f0:f1:55:01': 0.005523913264222876,
#  '40:31:3c:28:93:ee': 0.00549437362109869,
#  '40:b4:f0:f1:55:03': 0.005396523553249822,
#  '40:b4:f0:9b:f9:01': 0.005077126161969555,
#  '40:b4:f0:9b:f9:03': 0.005025431786502229,
#  '14:dd:a9:f0:eb:3c': 0.004811269373851877,
#  '28:28:5d:de:9e:3c': 0.0046801872074883,
#  '14:cc:20:7a:08:be': 0.0037293799444285463,
#  '9e:93:4e:78:1e:63': 0.0032881315252610106,
#  'd4:bf:7f:04:93:2c': 0.002977965272457052,
#  'bc:2e:f6:d6:c6:fc': 0.002822882146055073,
#  'ec:43:f6:dd:01:60': 0.0027822651367593165,
#  '48:5b:39:e7:e2:5c': 0.0027508792659398686,
#  '04:bf:6d:65:5f:42': 0.002621643327271552,
#  '74:d0:2b:68:93:14': 0.002617950871881029,
#  'c4:71:54:4b:ca:72': 0.002542255536375301,
#  '00:04:56:e9:d5:b7': 0.002521947031727423,
#  '28:d1:27:0d:8b:6c': 0.0023834799545827986,
#  '5e:ea:1d:32:bb:f0': 0.002376095043801752,
#  'b4:fb:e4:f4:05:8b': 0.0023354780345059955,
#  'b6:fb:e4:f4:05:8b': 0.0022874761144291923,
#  '04:8d:38:59:7d:81': 0.0022394741943523896,
#  '10:62:eb:20:a4:ee': 0.0019773098616252343,
#  'b4:fb:e4:f4:07:9f': 0.0016412964210876127,
#  'b6:fb:e4:f4:07:9f': 0.0015452925809340066,
#  '40:b4:f0:22:8d:c2': 0.0014751359285140636,
#  '30:f7:72:21:2d:0e': 0.001408671731484644,
#  '40:b4:f0:22:8d:c0': 0.0012129715957869085,
#  '3c:8a:b0:ff:c3:02': 0.001183431952662722,
#  '52:ff:20:42:f5:df': 0.0010874281125091158,
#  '52:ff:20:12:f5:df': 0.0010763507463375458,
#  '10:fe:ed:54:5b:ce': 0.001074504518642284,
#  'f0:9f:c2:b4:b2:f9': 0.0010283488262607427,
#  'b4:fb:e4:f5:05:8b': 0.0010228101431749579,
#  '50:ff:20:12:f5:df': 0.0010135790046986496,
#  'b6:fb:e4:f5:05:8b': 0.0010117327770033878}

# %%
df_2 = pd.read_csv(".\\_generated\\wifi_2.data", index_col = False, header = None, low_memory = False, \
                 names = ['timestamp', 'uuid', 'bssid', 'ssid', 'capabilities', \
                          'freq0', 'freq1', 'chwidth', 'freq', 'level', 'operator', \
                          'time', 'venue', '802', 'passpoint'])
df_3 = pd.read_csv(".\\_generated\\wifi_3.data", index_col = False, header = None, low_memory = False, \
                 names = ['timestamp', 'uuid', 'bssid', 'ssid', 'capabilities', \
                          'freq0', 'freq1', 'chwidth', 'freq', 'level', 'operator', \
                          'time', 'venue', '802', 'passpoint'])

df_ = pd.concat([df_2, df_3])

df_['timestamp'] = df_['timestamp'].apply(lambda x: dt.strptime(x, '%d.%m.%Y_%H:%M:%S.%f'))
df_.index = pd.DatetimeIndex(df_.timestamp)
df_ = df_.drop(df_.columns.difference(['uuid', 'bssid']), axis = 1)
df_ = df_.sort_index()

# %%
bssid_map_ = { key: 0 for key, value in bssid_map.items() }

def update_invalid_map(bssid):
    if bssid in bssid_map.keys():
        bssid_map[bssid] += 1
    return bssid

_ = df_.bssid.apply(lambda bssid: update_invalid_map(bssid))

# %%
bssid_map_
# Out:
# {'34:ce:00:4d:64:1e': 0,
#  '34:ce:00:4d:64:1d': 0,
#  '40:b4:f0:28:29:c3': 0,
#  '40:b4:f0:28:29:c1': 0,
#  '50:d4:f7:66:35:d0': 0,
#  '40:b4:f0:28:29:c2': 0,
#  '40:b4:f0:28:29:c0': 0,
#  'd4:6e:0e:a0:40:56': 0,
#  '20:4e:7f:75:b5:36': 0,
#  'b0:a8:6e:41:ec:c2': 0,
#  'b0:a8:6e:41:ec:c1': 0,
#  'b0:a8:6e:41:ec:c3': 0,
#  '3c:8a:b0:f9:27:02': 0,
#  'b0:a8:6e:41:ec:c0': 0,
#  '10:0e:7e:17:02:c2': 0,
#  '3c:8a:b0:f9:27:00': 0,
#  '10:0e:7e:17:02:c0': 0,
#  '50:64:2b:4e:08:dd': 0,
#  '2c:4d:54:5b:80:28': 0,
#  'b0:a8:6e:41:e4:82': 0,
#  'bc:ee:7b:68:0f:4c': 0,
#  '40:31:3c:28:93:ed': 0,
#  'b0:a8:6e:41:e4:80': 0,
#  'd8:47:32:c3:1b:90': 0,
#  'c0:25:e9:92:cc:5a': 0,
#  '5e:ea:1d:8b:34:df': 0,
#  '2c:fd:a1:05:25:c4': 0,
#  '40:b4:f0:9b:f9:00': 0,
#  'ec:08:6b:c9:c4:a0': 0,
#  '40:b4:f0:9b:f9:02': 0,
#  'f4:f2:6d:4c:5e:ea': 0,
#  '7c:8b:ca:2c:6c:a8': 0,
#  'ea:d8:d1:7a:da:af': 0,
#  '0c:8f:ff:81:2b:f8': 0,
#  '50:ff:20:1f:55:44': 0,
#  'fc:8b:97:54:97:ea': 0,
#  '74:d0:2b:69:2e:54': 0,
#  '30:b5:c2:3f:ab:e2': 0,
#  '10:0e:7e:17:02:c1': 0,
#  '10:0e:7e:17:02:c3': 0,
#  '40:b4:f0:f1:55:02': 0,
#  '40:b4:f0:22:ba:82': 0,
#  '40:b4:f0:f1:55:00': 0,
#  '40:b4:f0:22:ba:80': 0,
#  '40:b4:f0:f1:55:01': 0,
#  '40:31:3c:28:93:ee': 0,
#  '40:b4:f0:f1:55:03': 0,
#  '40:b4:f0:9b:f9:01': 0,
#  '40:b4:f0:9b:f9:03': 0,
#  '14:dd:a9:f0:eb:3c': 0,
#  '28:28:5d:de:9e:3c': 0,
#  '14:cc:20:7a:08:be': 0,
#  '9e:93:4e:78:1e:63': 0,
#  'd4:bf:7f:04:93:2c': 0,
#  'bc:2e:f6:d6:c6:fc': 0,
#  'ec:43:f6:dd:01:60': 0,
#  '48:5b:39:e7:e2:5c': 0,
#  '04:bf:6d:65:5f:42': 0,
#  '74:d0:2b:68:93:14': 0,
#  'c4:71:54:4b:ca:72': 0,
#  '00:04:56:e9:d5:b7': 0,
#  '28:d1:27:0d:8b:6c': 0,
#  '5e:ea:1d:32:bb:f0': 0,
#  'b4:fb:e4:f4:05:8b': 0,
#  'b6:fb:e4:f4:05:8b': 0,
#  '04:8d:38:59:7d:81': 0,
#  '10:62:eb:20:a4:ee': 0,
#  'b4:fb:e4:f4:07:9f': 0,
#  'b6:fb:e4:f4:07:9f': 0,
#  '40:b4:f0:22:8d:c2': 0,
#  '30:f7:72:21:2d:0e': 0,
#  '40:b4:f0:22:8d:c0': 0,
#  '3c:8a:b0:ff:c3:02': 0,
#  '52:ff:20:42:f5:df': 0,
#  '52:ff:20:12:f5:df': 0,
#  '10:fe:ed:54:5b:ce': 0,
#  'f0:9f:c2:b4:b2:f9': 0,
#  'b4:fb:e4:f5:05:8b': 0,
#  '50:ff:20:12:f5:df': 0,
#  'b6:fb:e4:f5:05:8b': 0}

# %%
sum_of_freq_ = 0
for key, value in bssid_map_.items():
    sum_of_freq_ += value
    
bssid_map_ = { key: value / sum_of_freq_ for key, value in bssid_map.items() }

# %%
bssid_map_

# %%
def agg_string_join(col):
    col = col.apply(lambda x: str(x))
    return col.str.cat(sep = ',').replace(' ', '')

# %%
df_quantum = df.groupby(['timestamp', 'uuid']).agg({'bssid' : agg_string_join})

# %%
df_quantum
# Out:
#                                                                                                           bssid
# timestamp               uuid
# 2020-12-06 17:56:05.536 b018455a-f744-4479-88c8-2328ad3efc5f  34:ce:00:4d:64:1d,b0:a8:6e:41:ec:c3,b0:a8:6e:4...
# 2020-12-06 17:56:08.521 615c3cad-870e-461b-b49f-bee42bdcc3e6  b0:a8:6e:41:e4:82,3c:8a:b0:f9:27:02,3c:8a:b0:f...
# 2020-12-06 17:56:12.036 db79802c-7f27-4cb5-bf03-2ce6e751b13f  3c:8a:b0:f9:27:00,3c:8a:b0:f9:27:02,10:0e:7e:1...
# 2020-12-06 17:56:19.939 03a1ca3e-5208-44e6-94ca-0f5f0242b98b  bc:ee:7b:68:0f:4c,34:ce:00:4d:64:1d,34:ce:00:4...
# 2020-12-06 17:56:26.836 841e61eb-5cd2-47a6-890e-28e61e254000  10:0e:7e:17:02:c2,d4:6e:0e:a0:40:56,fc:8b:97:5...
# 2020-12-06 17:56:30.335 6f976e70-5067-4136-b96d-6a6f9b30e801  40:b4:f0:28:29:c3,50:d4:f7:66:35:d0,40:b4:f0:2...
# 2020-12-06 17:56:34.951 706d09df-f988-4cff-871d-a1be3d267202  d4:6e:0e:a0:40:56,2c:fd:a1:05:25:c4,b0:a8:6e:4...
