# %%
from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, plot_roc_curve, make_scorer, f1_score, roc_auc_score, det_curve
from sklearn import preprocessing
from scipy import stats
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, LeaveOneGroupOut, PredefinedSplit, GridSearchCV
import matplotlib.pyplot as plt
import os
from sklearn import metrics

# %matplotlib inline

# %%
def concat_dataframes(path, df_type):
    dfs_list = []
    dfs_rows_len_list = []
    
    for user in os.listdir(path):
        for file in os.listdir(os.path.join(path, user)):
            if file.find(df_type) != -1:
                df = pd.read_csv(os.path.join(path, user, file))
                
                df = df.drop(["timestamp"], axis=1)
#                 df = (df - df.min()) / (df.max() - df.min())
                
                df["user"] = int(user.split('_')[1])
                
                dfs_list.append(df)
    
    return pd.concat(dfs_list, ignore_index=True)


def drop_bad_rows(df, z = 3):
    bad_rows = set()
    for col in df.columns:
        if col != "user":
            for user in df.user.unique():
                for x in list(df.loc[df.user == user, :][np.abs(stats.zscore(df.loc[df.user == user, col])) > z].index):
                    bad_rows.add(x)

            for x in list(df[col][np.abs(stats.zscore(df[col])) > z].index):
                bad_rows.add(x)

    df = df.drop(list(bad_rows), axis=0)

    return df


def drop_bad_cols(df, z = 3, allowed_proportion = 0.1):
    bad_cols = set()
    for col in df.columns:
        if col != "user":
            if df[df[col] != df[col].mean()].shape[0] < allowed_proportion * df.shape[0]:
                bad_cols.add(col)

            for user in df.user.unique():
                if df.loc[df.user == user, :][df.loc[df.user == user, col] != df.loc[df.user == user, col].mean()].shape[0] < allowed_proportion * df.loc[df.user == user, :].shape[0]:
                    bad_cols.add(col)

                elif np.sum(np.abs(stats.zscore(df.loc[df.user == user, col])) < z) < (1 - allowed_proportion) * df.loc[df.user == user, col].shape[0]:
                    bad_cols.add(col)

    df = df.drop(bad_cols, axis=1)
    return df, list(bad_cols)


def split_users_into_two_classes(df, valid_user_label, intruder_label):
    df.loc[df["user"] != valid_user_label, "user"] = intruder_label
    df.loc[df["user"] == valid_user_label, "user"] = 1
    return df  


def prepare_dataset(df, user, is_SVM=False):
    df_ = split_users_into_two_classes(df.copy(), user)
    
    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)
    
    if is_SVM:
        df_.loc[df_.user == 0, 'user'] = -1
    
    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]
    
    return X, y, group_labels


def create_file_for_results(data_type):
    res_folder = '.\\_results'
    if os.path.exists(res_folder) is False:
        os.makedirs(res_folder)
    
    file = os.path.join(res_folder, data_type + '_results.json')
    if os.path.exists(file) is False:
        with open(file, 'w') as f:
            json.dump({'stub': None}, f)
        
    return file    


def update_file_with_results(file_path, results_dict):
    import collections.abc

    def update(d, u):
        for k, v in u.items():
            if isinstance(v, collections.abc.Mapping):
                d[k] = update(d.get(k, {}), v)
            else:
                d[k] = v
        return d
    
    with open(file_path, 'r') as f:
        res = json.load(f)
    
    res = update(res, results_dict)
    
    with open(file_path, 'w') as f:
        json.dump(res, f, sort_keys=True, indent=2)
        
        
def get_dict_with_results(json_path):
    with open(json_path, 'r') as f:
        res = json.load(f)
    return res    


def get_dataframe(path, data_type, window_type, window_size):
    return concat_dataframes(os.path.join(path, window_type, window_size), data_type), create_file_for_results(data_type)


def drop_corr_columns(df, corr_coef):
    corr_matrix = df.corr().abs()
    upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
    corr_cols = [column for column in upper_tri.columns if any(abs(upper_tri[column]) > corr_coef) and column != "user"]
    return df.drop(corr_cols, axis=1), corr_cols

# %%
def get_train_split(df, valid_user, intruder, is_SVM = False):
    train_df = df[df.user != intruder]
    intruder_label = 0
    if is_SVM:
        intruder_label = -1
    train_df = split_users_into_two_classes(train_df.copy(), valid_user, intruder_label)   
    
    valid_user_count = train_df[train_df.user == 1].shape[0]
    intruder_count = train_df[train_df.user == intruder_label].shape[0]

    if valid_user_count < intruder_count:
        train_df = train_df.drop(train_df[train_df.user == intruder_label].sample(intruder_count - valid_user_count).index)
    else:
        train_df = train_df.drop(train_df[train_df.user == 1].sample(valid_user_count - intruder_count).index)
        
    dataset = train_df.to_numpy().copy()
    np.random.shuffle(dataset)

    X = dataset[:, :-1]
    y = dataset[:, -1]    
    
    return X, y


def process_train_df(df, features, data_type, corr = 0.7, z = 3, prop = 0.1): 
    df = df.drop(df.columns.difference(features), axis=1)
    df = df.dropna(how='all')
    df = df.fillna(0)
    
    df['nulls'] = (df == 0).sum(axis=1)
#     if data_type == 'bt':
#         df = df[df['nulls'] < 20]

    if 'count_mean' in df.columns:
        df = df[df.count_mean != 0]
        
    df = df.drop('nulls', axis=1)
    
    df = drop_bad_rows(df, z)
    df, dropped_cols_1 = drop_bad_cols(df, z, prop)
    df, dropped_cols_2 = drop_corr_columns(df, corr)
    
    return df, dropped_cols_1 + dropped_cols_2


def get_test_split(df, cols_for_drop, is_SVM = False):
    events_count = df.events_count.to_numpy()
    df = df.drop(cols_for_drop + ['timestamp', 'events_count'], axis=1)
    # test_df = (test_df - test_df.min()) / (test_df.max() - test_df.min())
    df = df.fillna(0)
    
    if is_SVM:
        df.loc[df["user"] != 1, "user"] = -1
    
    test_dataset = df.to_numpy().copy()
    
    X_test = test_dataset[:, :-1]
    y_test = test_dataset[:, -1]
    
    return X_test, y_test, events_count


def get_test_df(
    data_path,
    events_wnd,
    window_type,
    window_size,
    valid_user,
    intruder,
    data_type,
    index_1,
    index_2
):
    test_df = pd.read_csv(
        os.path.join(
            data_path,
            events_wnd,
            window_type,
            window_size,
            "_".join(["user", str(valid_user)]),
            "_".join([str(data_type), str(index_1), str(index_2), str(intruder)]) + ".data.csv",
        )
    )
    
    if 'count_mean' in test_df.columns:
        test_df = test_df[test_df['count_mean'] != 0]
    
    test_df = test_df.rename(columns={'user_user_agg': 'user', 'events_count_sum': 'events_count'})
    return test_df


def test_model(
    results_file,
    model,
    X_test,
    y_test,
    model_tag,
    df_type,
    window_type,
    window_size,
    valid_user,
    intruder,
    index_1,
    index_2,
    events_count,
    is_SVM = False
):
    predict = model.predict(X_test)
    if is_SVM:
        proba = model.decision_function(X_test)
    else:
        proba = model.predict_proba(X_test)
       
    print("TYPE: ", df_type)
    print('Model = ', model_tag, ', valid user = ', valid_user, ', intruder = ', intruder, ", ", index_1, '_', index_2)    
    print("--------------------------------------------------------------------------------")
        
    results = {
        df_type: {
            window_type: {
                window_size: {
                    model_tag: {
                        "valid_user": {
                            str(valid_user): {
                                "intruder": {
                                    str(intruder): {
                                        "valid_sample_index": {
                                            str(index_1): {
                                                "intruder_sample_index": {
                                                    str(index_2): {
                                                        "test": y_test.tolist(),
                                                        "predict": predict.tolist(),
                                                        "proba": proba.tolist(),
                                                        "events_count": events_count.tolist()
                                                    }
                                                }
                                            }
                                        }
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }    
    
#     update_file_with_results(results_file, results)
    print('Accuracy score = ', accuracy_score(y_test, predict))
    print("--------------------------------------------------------------------------------")
    
    
def simulate(
    users_count,
    samples_count,
    model,
    model_tag,
    data_path,
    test_data_path,
    df_type,
    events_wnd,
    window_type,
    window_size,
    is_SVM = False,
):   
    for valid_user in range(1, users_count + 1):
        for intruder in range(1, users_count + 1):
            if valid_user != intruder:
                df, results_file = get_dataframe(data_path, df_type, window_type, window_size)
                features = df.columns.to_list()
                df, dropped_cols = process_train_df(df, features, df_type)
                X_train, y_train = get_train_split(df, valid_user, intruder, is_SVM)

                model.fit(X_train, y_train)

                for valid_user_sample in range(samples_count):
                    for intruder_sample in range(samples_count):
                        test_df = get_test_df(
                            test_data_path,
                            events_wnd,
                            window_type,
                            window_size,
                            valid_user,
                            intruder,
                            df_type,
                            index_1=valid_user_sample,
                            index_2=intruder_sample,
                        )

                        X_test, y_test, events_count = get_test_split(test_df, dropped_cols, is_SVM)

                        test_model(
                            results_file,
                            model,
                            X_test,
                            y_test,
                            model_tag,
                            df_type,
                            window_type,
                            window_size,
                            valid_user,
                            intruder,
                            index_1=valid_user_sample,
                            index_2=intruder_sample,
                            events_count=events_count,
                            is_SVM=False,
                        )

# %% [markdown]
# ### Simulation settings
# ### ***

# %%
DATA_PATH = '..\\..\\scripts\\_features_all'
TEST_DATA_PATH = '..\\..\\scripts\\_features_events_full'

EVENTS_WND = '15min'

DATA_TYPE = "location"

WINDOW_TYPE = "rolling"
WINDOW_SIZE = "60s"

SAMPLES_COUNT = 10
USERS_COUNT = 8

model_params = {
    "n_estimators": 100,
    "criterion": "gini",
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 1,
    "max_features": "auto",
    "n_jobs": -1,
    "class_weight": "balanced",
}

model = RandomForestClassifier(**model_params)

# %%
DATA_TYPES = ["location", "wifi", "bt"]
WINDOW_SIZES = ['60s']
WINDOW_TYPES = ['rolling', 'sampling'   ]

# %% [markdown]
# ### ***

# %%
for data_type in DATA_TYPES:

# %%
simulate(
    USERS_COUNT,
    SAMPLES_COUNT,
    model,
    "RandomForest",
    DATA_PATH,
    TEST_DATA_PATH,
    DATA_TYPE,
    EVENTS_WND,
    WINDOW_TYPE,
    WINDOW_SIZE,
    is_SVM = False,
)
# Out:
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.69
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9442379182156134
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.7799227799227799
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9298245614035088
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.9662162162162162
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.9269406392694064
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9906542056074766
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  0 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.8368421052631579
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.958217270194986
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.836676217765043
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9727891156462585
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.9789915966386554
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.948220064724919
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9949238578680203
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  1 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.89198606271777
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9671052631578947
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.8721973094170403
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9836065573770492
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.9850746268656716
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.9605911330049262
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9965986394557823
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  2 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.8609865470852018
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9617346938775511
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.8507853403141361
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9777777777777777
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.981549815498155
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.9532163742690059
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9956521739130435
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  3 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.7047619047619048
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9452554744525548
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.7840909090909091
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9354838709677419
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.9673202614379085
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.9285714285714286
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9910714285714286
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  4 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.8686440677966102
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9629629629629629
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.8556962025316456
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9792746113989638
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.9823943661971831
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.9549295774647887
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9958847736625515
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  5 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.7876712328767124
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9523809523809523
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 2
# --------------------------------------------------------------------------------
# Accuracy score =  0.8131147540983606
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 3
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 4
# --------------------------------------------------------------------------------
# Accuracy score =  0.9611650485436893
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 5
# --------------------------------------------------------------------------------
# Accuracy score =  0.9742268041237113
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 6
# --------------------------------------------------------------------------------
# Accuracy score =  0.939622641509434
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 7
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 8
# --------------------------------------------------------------------------------
# Accuracy score =  0.9934640522875817
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  6 _ 9
# --------------------------------------------------------------------------------
# Accuracy score =  1.0
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  7 _ 0
# --------------------------------------------------------------------------------
# Accuracy score =  0.8697478991596639
# --------------------------------------------------------------------------------
# TYPE:  location
# Model =  RandomForest , valid user =  1 , intruder =  2 ,  7 _ 1
# --------------------------------------------------------------------------------
# Accuracy score =  0.9631449631449631
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c089dbaae860> in <module>
#      10     WINDOW_TYPE,
#      11     WINDOW_SIZE,
# ---> 12     is_SVM = False,
#      13 )
#
# <ipython-input-3-92cb88482199> in simulate(users_count, samples_count, model, model_tag, data_path, test_data_path, df_type, events_wnd, window_type, window_size, is_SVM)
#     205                             index_2=intruder_sample,
#     206                             events_count=events_count,
# --> 207                             is_SVM=False,
#     208                         )
#
# <ipython-input-3-92cb88482199> in test_model(results_file, model, X_test, y_test, model_tag, df_type, window_type, window_size, valid_user, intruder, index_1, index_2, events_count, is_SVM)
#     110         proba = model.decision_function(X_test)
#     111     else:
# --> 112         proba = model.predict_proba(X_test)
#     113
#     114     print("TYPE: ", df_type)
#
# D:\Program Files\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     685             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     686                                             lock)
# --> 687             for e in self.estimators_)
#     688
#     689         for proba in all_proba:
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# D:\Program Files\Anaconda3\Lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# D:\Program Files\Anaconda3\Lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# D:\Program Files\Anaconda3\Lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# D:\Program Files\Anaconda3\Lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
