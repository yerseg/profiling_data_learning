# %%
from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, plot_roc_curve, make_scorer, f1_score, roc_auc_score
from sklearn import preprocessing
from scipy import stats
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, LeaveOneGroupOut, PredefinedSplit, GridSearchCV
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def make_dataframe_impl(df_count, rolling=True):
    dfs_list = []
    dfs_rows_len_list = []

    file_name = ""
    if rolling is True:
        file_name = ".\\_datasets\\240s\\wifi_rolling_dataset_"
    else:
        file_name = ".\\_datasets\\240s\\wifi_sampling_dataset_"

    for i in range(1, df_count + 1):
        df = pd.read_csv(file_name + str(i) + ".csv")
        df = df.drop(["timestamp"], axis=1)

        df = (df - df.min()) / (df.max() - df.min())

        df["user"] = i
        dfs_list.append(df)
        dfs_rows_len_list.append(df.shape[0])

    df = pd.concat(dfs_list, ignore_index=True)
    return df

# %%
def make_common_rolling_dataframe(df_count):
    return make_dataframe_impl(df_count, True)


def make_common_sampling_dataframe(df_count):
    return make_dataframe_impl(df_count, False)

# %%
def drop_bad_rows(df):
    bad_rows = set()
    for col in df.columns:
        if col != "user":
            for user in df.user.unique():
                for x in list(
                    df.loc[df.user == user, :][
                        np.abs(stats.zscore(df.loc[df.user == user, col])) > 3
                    ].index
                ):
                    bad_rows.add(x)

            for x in list(df[col][np.abs(stats.zscore(df[col])) > 3].index):
                bad_rows.add(x)

    df.drop(list(bad_rows), axis=0, inplace=True)

    return df

def drop_bad_cols(df):
    bad_cols = set()
    for col in df.columns:
        if col != "user":
            if df[df[col] != df[col].mean()].shape[0] < 0.1 * df.shape[0]:
                bad_cols.add(col)

            for user in df.user.unique():
                if (
                    df.loc[df.user == user, :][
                        df.loc[df.user == user, col]
                        != df.loc[df.user == user, col].mean()
                    ].shape[0]
                    < 0.1 * df.loc[df.user == user, :].shape[0]
                ):
                    bad_cols.add(col)

                elif (
                    np.sum(np.abs(stats.zscore(df.loc[df.user == user, col])) < 3)
                    < 0.9 * df.loc[df.user == user, col].shape[0]
                ):
                    bad_cols.add(col)

    df.drop(list(bad_cols), axis=1, inplace=True)

    return df

# %%
def resample(df):
    sampling_dfs = []
    need_count = 0

    for label, count in zip(df.user.value_counts().index, df.user.value_counts().values):
        if need_count == 0:
            need_count = count
            df_ = df[df.user == label]
            sampling_dfs.append(df_)
        else:
            df_ = df[df.user == label]
            df_over = df_.sample(need_count, replace=True, random_state=42)
            sampling_dfs.append(df_over)

    new_df = pd.concat(sampling_dfs)
    new_df = new_df.reset_index()

    return pd.concat(sampling_dfs)

def extract_delayed_user(df, user_label):
    df_user = df[df["user"] == user_label]
    df = df[df["user"] != user_label]
    return df_user, df

def split_users_into_two_classes(df, valid_user_label):
    df.loc[df["user"] != valid_user_label, "user"] = 0
    df.loc[df["user"] == valid_user_label, "user"] = 1
    return df

# %%
def get_cv_split(X, y, group_labels, valid_user_label):
    predefined_split_array = np.zeros(group_labels.shape[0])
    i = 0
    test_array = [x for x in range(group_labels.shape[0])]
    for test, _ in LeaveOneGroupOut().split(X, y, group_labels):
        diff = np.setdiff1d(test_array, test)
        if np.all(group_labels[diff[0] : diff[-1]] == valid_user_label) is np.bool_(True):
            for sample in diff:
                predefined_split_array[sample] = -1
        else:
            for sample in diff:
                predefined_split_array[sample] = i
            i += 1
    return predefined_split_array

# %%
df = make_common_rolling_dataframe(8)

# %%
df.columns.to_list()
# Out:
# ['level_mean',
#  'level_var',
#  'level_median',
#  'level_skew',
#  'level_kurt',
#  'count_mean',
#  'count_var',
#  'count_median',
#  'count_skew',
#  'count_kurt',
#  'conn_level_mean',
#  'conn_level_var',
#  'conn_level_median',
#  'conn_level_skew',
#  'conn_level_kurt',
#  'occured_nets_count_1_mean',
#  'occured_nets_count_1_var',
#  'occured_nets_count_1_median',
#  'occured_nets_count_1_skew',
#  'occured_nets_count_1_kurt',
#  'occured_nets_count_2_mean',
#  'occured_nets_count_2_mad',
#  'occured_nets_count_2_skew',
#  'occured_nets_count_3_mean',
#  'occured_nets_count_3_mad',
#  'occured_nets_count_3_skew',
#  'occured_nets_count_mean_mean',
#  'occured_nets_count_mean_mad',
#  'occured_nets_count_mean_skew',
#  'occured_nets_count_median_mean',
#  'occured_nets_count_median_mad',
#  'occured_nets_count_median_skew',
#  'occured_nets_count_var_mean',
#  'occured_nets_count_var_mad',
#  'occured_nets_count_var_skew',
#  'disappeared_nets_count_1_mean',
#  'disappeared_nets_count_1_mad',
#  'disappeared_nets_count_1_skew',
#  'disappeared_nets_count_2_mean',
#  'disappeared_nets_count_2_mad',
#  'disappeared_nets_count_2_skew',
#  'disappeared_nets_count_3_mean',
#  'disappeared_nets_count_3_mad',
#  'disappeared_nets_count_3_skew',
#  'disappeared_nets_count_mean_mean',
#  'disappeared_nets_count_mean_mad',
#  'disappeared_nets_count_mean_skew',
#  'disappeared_nets_count_median_mean',
#  'disappeared_nets_count_median_mad',
#  'disappeared_nets_count_median_skew',
#  'disappeared_nets_count_var_mean',
#  'disappeared_nets_count_var_mad',
#  'disappeared_nets_count_var_skew',
#  'jaccard_index_1_mean',
#  'jaccard_index_1_mad',
#  'jaccard_index_1_skew',
#  'jaccard_index_2_mean',
#  'jaccard_index_2_mad',
#  'jaccard_index_2_skew',
#  'jaccard_index_3_mean',
#  'jaccard_index_3_mad',
#  'jaccard_index_3_skew',
#  'jaccard_index_mean_mean',
#  'jaccard_index_mean_mad',
#  'jaccard_index_mean_skew',
#  'jaccard_index_median_mean',
#  'jaccard_index_median_mad',
#  'jaccard_index_median_skew',
#  'jaccard_index_var_mean',
#  'jaccard_index_var_mad',
#  'jaccard_index_var_skew',
#  'occur_speed_1_mean',
#  'occur_speed_1_mad',
#  'occur_speed_1_skew',
#  'occur_speed_2_mean',
#  'occur_speed_2_mad',
#  'occur_speed_2_skew',
#  'occur_speed_3_mean',
#  'occur_speed_3_mad',
#  'occur_speed_3_skew',
#  'occur_speed_mean_mean',
#  'occur_speed_mean_mad',
#  'occur_speed_mean_skew',
#  'occur_speed_median_mean',
#  'occur_speed_median_mad',
#  'occur_speed_median_skew',
#  'occur_speed_var_mean',
#  'occur_speed_var_mad',
#  'occur_speed_var_skew',
#  'level_speed_1_mean',
#  'level_speed_1_mad',
#  'level_speed_1_skew',
#  'level_speed_2_mean',
#  'level_speed_2_mad',
#  'level_speed_2_skew',
#  'level_speed_3_mean',
#  'level_speed_3_mad',
#  'level_speed_3_skew',
#  'level_speed_mean_mean',
#  'level_speed_mean_mad',
#  'level_speed_mean_skew',
#  'level_speed_median_mean',
#  'level_speed_median_mad',
#  'level_speed_median_skew',
#  'level_speed_var_mean',
#  'level_speed_var_mad',
#  'level_speed_var_skew',
#  'conn_level_speed_1_mean',
#  'conn_level_speed_1_mad',
#  'conn_level_speed_1_skew',
#  'conn_level_speed_2_mean',
#  'conn_level_speed_2_mad',
#  'conn_level_speed_2_skew',
#  'conn_level_speed_3_mean',
#  'conn_level_speed_3_mad',
#  'conn_level_speed_3_skew',
#  'conn_level_speed_mean_mean',
#  'conn_level_speed_mean_mad',
#  'conn_level_speed_mean_skew',
#  'conn_level_speed_median_mean',
#  'conn_level_speed_median_mad',
#  'conn_level_speed_median_skew',
#  'conn_level_speed_var_mean',
#  'conn_level_speed_var_mad',
#  'conn_level_speed_var_skew',
#  'count_speed_1_mean',
#  'count_speed_1_mad',
#  'count_speed_1_skew',
#  'count_speed_2_mean',
#  'count_speed_2_mad',
#  'count_speed_2_skew',
#  'count_speed_3_mean',
#  'count_speed_3_mad',
#  'count_speed_3_skew',
#  'count_speed_mean_mean',
#  'count_speed_mean_mad',
#  'count_speed_mean_skew',
#  'count_speed_median_mean',
#  'count_speed_median_mad',
#  'count_speed_median_skew',
#  'count_speed_var_mean',
#  'count_speed_var_mad',
#  'count_speed_var_skew',
#  'acceleration_occured_nets_count_mean_1_mean',
#  'acceleration_occured_nets_count_mean_1_mad',
#  'acceleration_occured_nets_count_mean_1_skew',
#  'acceleration_occured_nets_count_mean_2_mean',
#  'acceleration_occured_nets_count_mean_2_mad',
#  'acceleration_occured_nets_count_mean_2_skew',
#  'acceleration_occured_nets_count_mean_3_mean',
#  'acceleration_occured_nets_count_mean_3_mad',
#  'acceleration_occured_nets_count_mean_3_skew',
#  'acceleration_occured_nets_count_mean_mean_mean',
#  'acceleration_occured_nets_count_mean_mean_mad',
#  'acceleration_occured_nets_count_mean_mean_skew',
#  'acceleration_occured_nets_count_mean_median_mean',
#  'acceleration_occured_nets_count_mean_median_mad',
#  'acceleration_occured_nets_count_mean_median_skew',
#  'acceleration_occured_nets_count_mean_var_mean',
#  'acceleration_occured_nets_count_mean_var_mad',
#  'acceleration_occured_nets_count_mean_var_skew',
#  'acceleration_jaccard_index_mean_1_mean',
#  'acceleration_jaccard_index_mean_1_mad',
#  'acceleration_jaccard_index_mean_1_skew',
#  'acceleration_jaccard_index_mean_2_mean',
#  'acceleration_jaccard_index_mean_2_mad',
#  'acceleration_jaccard_index_mean_2_skew',
#  'acceleration_jaccard_index_mean_3_mean',
#  'acceleration_jaccard_index_mean_3_mad',
#  'acceleration_jaccard_index_mean_3_skew',
#  'acceleration_jaccard_index_mean_mean_mean',
#  'acceleration_jaccard_index_mean_mean_mad',
#  'acceleration_jaccard_index_mean_mean_skew',
#  'acceleration_jaccard_index_mean_median_mean',
#  'acceleration_jaccard_index_mean_median_mad',
#  'acceleration_jaccard_index_mean_median_skew',
#  'acceleration_jaccard_index_mean_var_mean',
#  'acceleration_jaccard_index_mean_var_mad',
#  'acceleration_jaccard_index_mean_var_skew',
#  'acceleration_occur_speed_mean_1_mean',
#  'acceleration_occur_speed_mean_1_mad',
#  'acceleration_occur_speed_mean_1_skew',
#  'acceleration_occur_speed_mean_2_mean',
#  'acceleration_occur_speed_mean_2_mad',
#  'acceleration_occur_speed_mean_2_skew',
#  'acceleration_occur_speed_mean_3_mean',
#  'acceleration_occur_speed_mean_3_mad',
#  'acceleration_occur_speed_mean_3_skew',
#  'acceleration_occur_speed_mean_mean_mean',
#  'acceleration_occur_speed_mean_mean_mad',
#  'acceleration_occur_speed_mean_mean_skew',
#  'acceleration_occur_speed_mean_median_mean',
#  'acceleration_occur_speed_mean_median_mad',
#  'acceleration_occur_speed_mean_median_skew',
#  'acceleration_occur_speed_mean_var_mean',
#  'acceleration_occur_speed_mean_var_mad',
#  'acceleration_occur_speed_mean_var_skew',
#  'acceleration_disappeared_nets_count_mean_1_mean',
#  'acceleration_disappeared_nets_count_mean_1_mad',
#  'acceleration_disappeared_nets_count_mean_1_skew',
#  'acceleration_disappeared_nets_count_mean_2_mean',
#  'acceleration_disappeared_nets_count_mean_2_mad',
#  'acceleration_disappeared_nets_count_mean_2_skew',
#  'acceleration_disappeared_nets_count_mean_3_mean',
#  'acceleration_disappeared_nets_count_mean_3_mad',
#  'acceleration_disappeared_nets_count_mean_3_skew',
#  'acceleration_disappeared_nets_count_mean_mean_mean',
#  'acceleration_disappeared_nets_count_mean_mean_mad',
#  'acceleration_disappeared_nets_count_mean_mean_skew',
#  'acceleration_disappeared_nets_count_mean_median_mean',
#  'acceleration_disappeared_nets_count_mean_median_mad',
#  'acceleration_disappeared_nets_count_mean_median_skew',
#  'acceleration_disappeared_nets_count_mean_var_mean',
#  'acceleration_disappeared_nets_count_mean_var_mad',
#  'acceleration_disappeared_nets_count_mean_var_skew',
#  'acceleration_conn_level_speed_mean_1_mean',
#  'acceleration_conn_level_speed_mean_1_mad',
#  'acceleration_conn_level_speed_mean_1_skew',
#  'acceleration_conn_level_speed_mean_2_mean',
#  'acceleration_conn_level_speed_mean_2_mad',
#  'acceleration_conn_level_speed_mean_2_skew',
#  'acceleration_conn_level_speed_mean_3_mean',
#  'acceleration_conn_level_speed_mean_3_mad',
#  'acceleration_conn_level_speed_mean_3_skew',
#  'acceleration_conn_level_speed_mean_mean_mean',
#  'acceleration_conn_level_speed_mean_mean_mad',
#  'acceleration_conn_level_speed_mean_mean_skew',
#  'acceleration_conn_level_speed_mean_median_mean',
#  'acceleration_conn_level_speed_mean_median_mad',
#  'acceleration_conn_level_speed_mean_median_skew',
#  'acceleration_conn_level_speed_mean_var_mean',
#  'acceleration_conn_level_speed_mean_var_mad',
#  'acceleration_conn_level_speed_mean_var_skew',
#  'acceleration_count_speed_mean_1_mean',
#  'acceleration_count_speed_mean_1_mad',
#  'acceleration_count_speed_mean_1_skew',
#  'acceleration_count_speed_mean_2_mean',
#  'acceleration_count_speed_mean_2_mad',
#  'acceleration_count_speed_mean_2_skew',
#  'acceleration_count_speed_mean_3_mean',
#  'acceleration_count_speed_mean_3_mad',
#  'acceleration_count_speed_mean_3_skew',
#  'acceleration_count_speed_mean_mean_mean',
#  'acceleration_count_speed_mean_mean_mad',
#  'acceleration_count_speed_mean_mean_skew',
#  'acceleration_count_speed_mean_median_mean',
#  'acceleration_count_speed_mean_median_mad',
#  'acceleration_count_speed_mean_median_skew',
#  'acceleration_count_speed_mean_var_mean',
#  'acceleration_count_speed_mean_var_mad',
#  'acceleration_count_speed_mean_var_skew',
#  'user']

# %%
features = ['level_mean',
 'level_var',
 'level_median',
 'level_skew',
 'level_kurt',
 'count_mean',
 'count_var',
 'count_median',
 'count_skew',
 'count_kurt',
 'conn_level_mean',
 'conn_level_var',
 'conn_level_median',
 'conn_level_skew',
 'conn_level_kurt',
#  'occured_nets_count_1_mean',
#  'occured_nets_count_1_var',
#  'occured_nets_count_1_median',
#  'occured_nets_count_1_skew',
#  'occured_nets_count_1_kurt',
#  'occured_nets_count_2_mean',
#  'occured_nets_count_2_mad',
#  'occured_nets_count_2_skew',
#  'occured_nets_count_3_mean',
#  'occured_nets_count_3_mad',
#  'occured_nets_count_3_skew',
 'occured_nets_count_mean_mean',
 'occured_nets_count_mean_mad',
 'occured_nets_count_mean_skew',
 'occured_nets_count_median_mean',
 'occured_nets_count_median_mad',
 'occured_nets_count_median_skew',
 'occured_nets_count_var_mean',
 'occured_nets_count_var_mad',
 'occured_nets_count_var_skew',
#  'disappeared_nets_count_1_mean',
#  'disappeared_nets_count_1_mad',
#  'disappeared_nets_count_1_skew',
#  'disappeared_nets_count_2_mean',
#  'disappeared_nets_count_2_mad',
#  'disappeared_nets_count_2_skew',
#  'disappeared_nets_count_3_mean',
#  'disappeared_nets_count_3_mad',
#  'disappeared_nets_count_3_skew',
 'disappeared_nets_count_mean_mean',
 'disappeared_nets_count_mean_mad',
 'disappeared_nets_count_mean_skew',
 'disappeared_nets_count_median_mean',
 'disappeared_nets_count_median_mad',
 'disappeared_nets_count_median_skew',
 'disappeared_nets_count_var_mean',
 'disappeared_nets_count_var_mad',
 'disappeared_nets_count_var_skew',
#  'jaccard_index_1_mean',
#  'jaccard_index_1_mad',
#  'jaccard_index_1_skew',
#  'jaccard_index_2_mean',
#  'jaccard_index_2_mad',
#  'jaccard_index_2_skew',
#  'jaccard_index_3_mean',
#  'jaccard_index_3_mad',
#  'jaccard_index_3_skew',
 'jaccard_index_mean_mean',
 'jaccard_index_mean_mad',
 'jaccard_index_mean_skew',
 'jaccard_index_median_mean',
 'jaccard_index_median_mad',
 'jaccard_index_median_skew',
 'jaccard_index_var_mean',
 'jaccard_index_var_mad',
 'jaccard_index_var_skew',
#  'occur_speed_1_mean',
#  'occur_speed_1_mad',
#  'occur_speed_1_skew',
#  'occur_speed_2_mean',
#  'occur_speed_2_mad',
#  'occur_speed_2_skew',
#  'occur_speed_3_mean',
#  'occur_speed_3_mad',
#  'occur_speed_3_skew',
 'occur_speed_mean_mean',
 'occur_speed_mean_mad',
 'occur_speed_mean_skew',
 'occur_speed_median_mean',
 'occur_speed_median_mad',
 'occur_speed_median_skew',
 'occur_speed_var_mean',
 'occur_speed_var_mad',
 'occur_speed_var_skew',
#  'level_speed_1_mean',
#  'level_speed_1_mad',
#  'level_speed_1_skew',
#  'level_speed_2_mean',
#  'level_speed_2_mad',
#  'level_speed_2_skew',
#  'level_speed_3_mean',
#  'level_speed_3_mad',
#  'level_speed_3_skew',
 'level_speed_mean_mean',
 'level_speed_mean_mad',
 'level_speed_mean_skew',
 'level_speed_median_mean',
 'level_speed_median_mad',
 'level_speed_median_skew',
 'level_speed_var_mean',
 'level_speed_var_mad',
 'level_speed_var_skew',
#  'conn_level_speed_1_mean',
#  'conn_level_speed_1_mad',
#  'conn_level_speed_1_skew',
#  'conn_level_speed_2_mean',
#  'conn_level_speed_2_mad',
#  'conn_level_speed_2_skew',
#  'conn_level_speed_3_mean',
#  'conn_level_speed_3_mad',
#  'conn_level_speed_3_skew',
 'conn_level_speed_mean_mean',
 'conn_level_speed_mean_mad',
 'conn_level_speed_mean_skew',
 'conn_level_speed_median_mean',
 'conn_level_speed_median_mad',
 'conn_level_speed_median_skew',
 'conn_level_speed_var_mean',
 'conn_level_speed_var_mad',
 'conn_level_speed_var_skew',
#  'count_speed_1_mean',
#  'count_speed_1_mad',
#  'count_speed_1_skew',
#  'count_speed_2_mean',
#  'count_speed_2_mad',
#  'count_speed_2_skew',
#  'count_speed_3_mean',
#  'count_speed_3_mad',
#  'count_speed_3_skew',
 'count_speed_mean_mean',
 'count_speed_mean_mad',
 'count_speed_mean_skew',
 'count_speed_median_mean',
 'count_speed_median_mad',
 'count_speed_median_skew',
 'count_speed_var_mean',
 'count_speed_var_mad',
 'count_speed_var_skew',
#  'acceleration_occured_nets_count_mean_1_mean',
#  'acceleration_occured_nets_count_mean_1_mad',
#  'acceleration_occured_nets_count_mean_1_skew',
#  'acceleration_occured_nets_count_mean_2_mean',
#  'acceleration_occured_nets_count_mean_2_mad',
#  'acceleration_occured_nets_count_mean_2_skew',
#  'acceleration_occured_nets_count_mean_3_mean',
#  'acceleration_occured_nets_count_mean_3_mad',
#  'acceleration_occured_nets_count_mean_3_skew',
#  'acceleration_occured_nets_count_mean_mean_mean',
#  'acceleration_occured_nets_count_mean_mean_mad',
#  'acceleration_occured_nets_count_mean_mean_skew',
#  'acceleration_occured_nets_count_mean_median_mean',
#  'acceleration_occured_nets_count_mean_median_mad',
#  'acceleration_occured_nets_count_mean_median_skew',
#  'acceleration_occured_nets_count_mean_var_mean',
#  'acceleration_occured_nets_count_mean_var_mad',
#  'acceleration_occured_nets_count_mean_var_skew',
#  'acceleration_jaccard_index_mean_1_mean',
#  'acceleration_jaccard_index_mean_1_mad',
#  'acceleration_jaccard_index_mean_1_skew',
#  'acceleration_jaccard_index_mean_2_mean',
#  'acceleration_jaccard_index_mean_2_mad',
#  'acceleration_jaccard_index_mean_2_skew',
#  'acceleration_jaccard_index_mean_3_mean',
#  'acceleration_jaccard_index_mean_3_mad',
#  'acceleration_jaccard_index_mean_3_skew',
#  'acceleration_jaccard_index_mean_mean_mean',
#  'acceleration_jaccard_index_mean_mean_mad',
#  'acceleration_jaccard_index_mean_mean_skew',
#  'acceleration_jaccard_index_mean_median_mean',
#  'acceleration_jaccard_index_mean_median_mad',
#  'acceleration_jaccard_index_mean_median_skew',
#  'acceleration_jaccard_index_mean_var_mean',
#  'acceleration_jaccard_index_mean_var_mad',
#  'acceleration_jaccard_index_mean_var_skew',
#  'acceleration_occur_speed_mean_1_mean',
#  'acceleration_occur_speed_mean_1_mad',
#  'acceleration_occur_speed_mean_1_skew',
#  'acceleration_occur_speed_mean_2_mean',
#  'acceleration_occur_speed_mean_2_mad',
#  'acceleration_occur_speed_mean_2_skew',
#  'acceleration_occur_speed_mean_3_mean',
#  'acceleration_occur_speed_mean_3_mad',
#  'acceleration_occur_speed_mean_3_skew',
#  'acceleration_occur_speed_mean_mean_mean',
#  'acceleration_occur_speed_mean_mean_mad',
#  'acceleration_occur_speed_mean_mean_skew',
#  'acceleration_occur_speed_mean_median_mean',
#  'acceleration_occur_speed_mean_median_mad',
#  'acceleration_occur_speed_mean_median_skew',
#  'acceleration_occur_speed_mean_var_mean',
#  'acceleration_occur_speed_mean_var_mad',
#  'acceleration_occur_speed_mean_var_skew',
#  'acceleration_disappeared_nets_count_mean_1_mean',
#  'acceleration_disappeared_nets_count_mean_1_mad',
#  'acceleration_disappeared_nets_count_mean_1_skew',
#  'acceleration_disappeared_nets_count_mean_2_mean',
#  'acceleration_disappeared_nets_count_mean_2_mad',
#  'acceleration_disappeared_nets_count_mean_2_skew',
#  'acceleration_disappeared_nets_count_mean_3_mean',
#  'acceleration_disappeared_nets_count_mean_3_mad',
#  'acceleration_disappeared_nets_count_mean_3_skew',
#  'acceleration_disappeared_nets_count_mean_mean_mean',
#  'acceleration_disappeared_nets_count_mean_mean_mad',
#  'acceleration_disappeared_nets_count_mean_mean_skew',
#  'acceleration_disappeared_nets_count_mean_median_mean',
#  'acceleration_disappeared_nets_count_mean_median_mad',
#  'acceleration_disappeared_nets_count_mean_median_skew',
#  'acceleration_disappeared_nets_count_mean_var_mean',
#  'acceleration_disappeared_nets_count_mean_var_mad',
#  'acceleration_disappeared_nets_count_mean_var_skew',
#  'acceleration_conn_level_speed_mean_1_mean',
#  'acceleration_conn_level_speed_mean_1_mad',
#  'acceleration_conn_level_speed_mean_1_skew',
#  'acceleration_conn_level_speed_mean_2_mean',
#  'acceleration_conn_level_speed_mean_2_mad',
#  'acceleration_conn_level_speed_mean_2_skew',
#  'acceleration_conn_level_speed_mean_3_mean',
#  'acceleration_conn_level_speed_mean_3_mad',
#  'acceleration_conn_level_speed_mean_3_skew',
#  'acceleration_conn_level_speed_mean_mean_mean',
#  'acceleration_conn_level_speed_mean_mean_mad',
#  'acceleration_conn_level_speed_mean_mean_skew',
#  'acceleration_conn_level_speed_mean_median_mean',
#  'acceleration_conn_level_speed_mean_median_mad',
#  'acceleration_conn_level_speed_mean_median_skew',
#  'acceleration_conn_level_speed_mean_var_mean',
#  'acceleration_conn_level_speed_mean_var_mad',
#  'acceleration_conn_level_speed_mean_var_skew',
#  'acceleration_count_speed_mean_1_mean',
#  'acceleration_count_speed_mean_1_mad',
#  'acceleration_count_speed_mean_1_skew',
#  'acceleration_count_speed_mean_2_mean',
#  'acceleration_count_speed_mean_2_mad',
#  'acceleration_count_speed_mean_2_skew',
#  'acceleration_count_speed_mean_3_mean',
#  'acceleration_count_speed_mean_3_mad',
#  'acceleration_count_speed_mean_3_skew',
#  'acceleration_count_speed_mean_mean_mean',
#  'acceleration_count_speed_mean_mean_mad',
#  'acceleration_count_speed_mean_mean_skew',
#  'acceleration_count_speed_mean_median_mean',
#  'acceleration_count_speed_mean_median_mad',
#  'acceleration_count_speed_mean_median_skew',
#  'acceleration_count_speed_mean_var_mean',
#  'acceleration_count_speed_mean_var_mad',
#  'acceleration_count_speed_mean_var_skew',
 'user' ]

# %%
df = df.drop(df.columns.difference(features), axis=1)
df = df.dropna(how='all')
df = df.fillna(0)

# %%
df = drop_bad_cols(df)
df = drop_bad_rows(df)

# %%
fig = plt.figure(figsize=(20, 25))
plt.matshow(df.corr(), fignum=fig.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=18, rotation=90)
plt.yticks(range(df.shape[1]), df.columns, fontsize=18)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=16)
plt.title("Correlation matrix", fontsize=20, y=-0.03)
# Out:
# Text(0.5, -0.03, 'Correlation matrix')

# %%
corr_matrix = df.corr().abs()
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
corr_cols = [column for column in upper_tri.columns if any(abs(upper_tri[column]) > 0.7) and column != "user"]
df = df.drop(corr_cols, axis=1)

# %%
# sample = df.sample(10000)
# plt.figure(figsize=(16, 10))
# plt.scatter(x=sample['conn_level_mean'], y=sample['count_speed_var_skew'], alpha=0.5, c=sample.user, cmap='magma')
# plt.colorbar()
# plt.show()

# %%
# for user in df.user.unique():
#     for valid_user in df.user.unique():
#         if user != valid_user:
#             print('---------------------------------------------------------------------------')
#             print('Valid user: ', valid_user, 'Extracted user: ', user)
#             print('---------------------------------------------------------------------------')
#             df1, df_ = extract_delayed_user(df.copy(), user)
#             df1['user'] = 0
#             df_ = split_users_into_two_classes(df_.copy(), valid_user)
#             df_ = resample(df_)

#             dataset = df_.to_numpy()
#             X = dataset[:, :-1]
#             y = dataset[:, -1]

#             X_test = df1.to_numpy()[:, :-1]
#             y_test = df1.to_numpy()[:, -1]
            
#             model = CatBoostClassifier(iterations=100, depth=6, loss_function='Logloss')
#             model.fit(X, y, verbose=False)

#             preds_class = model.predict(X_test)
#             print('Accuracy: ', accuracy_score(preds_class, y_test))

#             sum_ = 0
#             imp = [ (x, i) for x, i in zip(model.feature_importances_, range(len(model.feature_importances_)) )]
#             sorted_ = sorted(imp, key=lambda tup: tup[0])
#             for i in range(len(sorted_)):
#                 if sorted_[i][0] > 5:
#                     print(sorted_[i][1], ': ', df_.columns[sorted_[i][1]], ' - ', sorted_[i][0])

#             print('---------------------------------------------------------------------------')
#             print('---------------------------------------------------------------------------')

# %% [markdown]
# ## CatBoostClassifier CV

# %%
iterations = 100
depth = 6
loss_function = 'Logloss'
l2_leaf_reg = 1
leaf_estimation_iterations = 5
logging_level = 'Silent'

df['labels'] = df['user']

CV_CATBOOST_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_.copy(), user)
    df_ = resample(df_)
    
    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)
    
    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]
    
    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))
    scoring = ('accuracy', 'balanced_accuracy')
    
    model = CatBoostClassifier(iterations=iterations, depth=depth, loss_function=loss_function, \
                               l2_leaf_reg=l2_leaf_reg, leaf_estimation_iterations=leaf_estimation_iterations,\
                               logging_level=logging_level)
    
    cv_results = cross_validate(model, X, y, scoring=scoring, cv=cv_split, n_jobs=-1)
    accuracy = cv_results['test_accuracy']
    
    CV_CATBOOST_BIG_DICT[str(user)] = {}
    CV_CATBOOST_BIG_DICT[str(user)]["accuracy"] = accuracy.copy()
    CV_CATBOOST_BIG_DICT[str(user)]["mean_accuracy"] = np.mean(accuracy).copy()
    CV_CATBOOST_BIG_DICT[str(user)]["max_accuracy"] = np.max(accuracy).copy()
    CV_CATBOOST_BIG_DICT[str(user)]["min_accuracy"] = np.min(accuracy).copy()
    
    print("CV accuracy list: ", accuracy)
    print("CV mean accuracy: ", np.mean(accuracy))
    print("CV min accuracy: ", np.min(accuracy))
    print("CV max accuracy: ", np.max(accuracy))
    
    print("--------------------------------------------------------------------------------")
# Out:
# Valid User:  1
# --------------------------------------------------------------------------------
# CV accuracy list:  [0.99696959 1.         0.25502542 0.07289808 1.         1.        ]
# CV mean accuracy:  0.7208155156739284
# CV min accuracy:  0.07289807737634264
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  2
# --------------------------------------------------------------------------------
# CV accuracy list:  [0.94646284 1.         1.         0.96609313 0.63328732 0.91885249]
# CV mean accuracy:  0.9107826301671212
# CV min accuracy:  0.6332873160712482
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  3
# --------------------------------------------------------------------------------
# CV accuracy list:  [1.         1.         1.         1.         1.         0.95158086]
# CV mean accuracy:  0.9919301435514103
# CV min accuracy:  0.9515808613084615
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  4
# --------------------------------------------------------------------------------
# CV accuracy list:  [1. 1. 1. 1. 1. 1.]
# CV mean accuracy:  1.0
# CV min accuracy:  1.0
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  5
# --------------------------------------------------------------------------------
# CV accuracy list:  [0.98289505 0.96191791 1.         1.         0.99784505 0.97814741]
# CV mean accuracy:  0.9868009023872859
# CV min accuracy:  0.9619179096939291
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  7
# --------------------------------------------------------------------------------
# CV accuracy list:  [0.99831644 0.99377083 1.         0.33607192 1.         0.99959595]
# CV mean accuracy:  0.8879591905451361
# CV min accuracy:  0.33607192161352234
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  8
# --------------------------------------------------------------------------------
# CV accuracy list:  [1.         0.95612647 0.         1.         1.         1.        ]
# CV mean accuracy:  0.8260210781507795
# CV min accuracy:  0.0
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------

# %% [markdown]
# ## CatBoostClassifier Final Validation

# %%
iterations = 100
depth = 6
loss_function = 'Logloss'
l2_leaf_reg = 1
leaf_estimation_iterations = 5
logging_level = 'Silent'

df["labels"] = df["user"]

VALIDATION_CATBOOST_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    VALIDATION_CATBOOST_BIG_DICT[str(user)] = {}

    for ex_user in df.labels.unique():
        if ex_user != user:

            df_ = df.copy()

            df_for_test = []

            df__ = df_[df_.labels == ex_user].copy()
            df_for_test.append(df__)
            df_ = df_.drop(df__.index, axis=0)

            for user_ in df_.labels.unique():
                if user_ != ex_user:
                    test_size = int((0.25 * df_[df_.labels == user_].shape[0]) - 1)
                    df__ = df_[df_.labels == user_].sample(test_size).copy()
                    df_for_test.append(df__)
                    df_ = df_.drop(df__.index, axis=0)

            df_ = resample(df_.copy())
            df_ = split_users_into_two_classes(df_.copy(), user)
            df_ = resample(df_)

            df_ = df_.drop("labels", axis=1)

            dataset = df_.to_numpy().copy()
            np.random.shuffle(dataset)

            X = dataset[:, :-1]
            y = dataset[:, -1]

            model = CatBoostClassifier(iterations=iterations, depth=depth, loss_function=loss_function, \
                                       l2_leaf_reg=l2_leaf_reg, leaf_estimation_iterations=leaf_estimation_iterations, \
                                       logging_level=logging_level)
            model.fit(X, y)

            # Testing

            test_df = pd.concat(df_for_test)

            valid_user_in_test_count = test_df[test_df.labels == user].shape[0]
            ex_user_in_test_count = test_df[test_df.labels == ex_user].shape[0]
            others_in_test_count = [test_df[test_df.labels == x].shape[0] \
                                    for x in test_df.labels.unique() if x != user and x != ex_user]

            min_others_test_count = min(others_in_test_count)

            is_important_min = True
            if min_others_test_count <= ex_user_in_test_count and min_others_test_count <= valid_user_in_test_count:
                is_important_min = False

            new_df_parts = []
            if is_important_min is True:
                part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                other_sample_size = part_size // len(others_in_test_count) + 1

            else:
                part_size_can_be = min_others_test_count * len(others_in_test_count)
                        
                if part_size_can_be > min(valid_user_in_test_count, ex_user_in_test_count):
                    part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                    other_sample_size = part_size // len(others_in_test_count) + 1
                else:
                    part_size = part_size_can_be
                    other_sample_size = min_others_test_count
                    
            new_df_parts.append(test_df[test_df.labels == user].sample(part_size).copy())
            new_df_parts.append(test_df[test_df.labels == ex_user].sample(part_size).copy())

            for x in test_df.labels.unique():
                if x != user and x != ex_user:
                    new_df_parts.append(test_df[test_df.labels == x].sample(other_sample_size).copy())
                    
            test_df = pd.concat(new_df_parts)

            test_df.loc[test_df.labels != user, "user"] = 0
            test_df.loc[test_df.labels == user, "user"] = 1

            print("True: ", test_df[test_df.user == 1].shape)
            print("Shape: ", test_df.shape)
            for x in test_df.labels.unique():
                print("Count ", x, ": ", test_df[test_df.labels == x].shape)

            test_df = test_df.drop("labels", axis=1)

            test_dataset = test_df.to_numpy().copy()
            X_test = test_dataset[:, :-1].copy()
            y_test = test_dataset[:, -1].copy()
            
            VALIDATION_CATBOOST_BIG_DICT[str(user)][ex_user] = {}
            VALIDATION_CATBOOST_BIG_DICT[str(user)][ex_user]["y_test"] = y_test.copy()
            VALIDATION_CATBOOST_BIG_DICT[str(user)][ex_user]["y_predict"] = model.predict(X_test).copy()
            VALIDATION_CATBOOST_BIG_DICT[str(user)][ex_user]["y_proba"] = model.predict_proba(X_test).copy()

            print("Valid user = ", user, ", Extracted user = ", ex_user, "accuracy = ",
                    accuracy_score(VALIDATION_CATBOOST_BIG_DICT[str(user)][ex_user]["y_test"], 
                                   VALIDATION_CATBOOST_BIG_DICT[str(user)][ex_user]["y_predict"])
                 )

            print("--------------------------------------------------------------------------------")
# Out:
# Valid User:  1
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  1 :  (120, 23)
# Count  2 :  (120, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  1 , Extracted user =  2 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  1 :  (120, 23)
# Count  3 :  (120, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  1 , Extracted user =  3 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (101, 23)
# Shape:  (307, 23)
# Count  1 :  (101, 23)
# Count  4 :  (101, 23)
# Count  2 :  (21, 23)
# Count  3 :  (21, 23)
# Count  5 :  (21, 23)
# Count  7 :  (21, 23)
# Count  8 :  (21, 23)
# Valid user =  1 , Extracted user =  4 accuracy =  0.7817589576547231
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  1 :  (120, 23)
# Count  5 :  (120, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  1 , Extracted user =  5 accuracy =  0.6944444444444444
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  1 :  (120, 23)
# Count  7 :  (120, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  1 , Extracted user =  7 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  1 :  (120, 23)
# Count  8 :  (120, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  1 , Extracted user =  8 accuracy =  1.0
# --------------------------------------------------------------------------------
# Valid User:  2
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  2 :  (120, 23)
# Count  1 :  (120, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  2 , Extracted user =  1 accuracy =  0.975
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  2 :  (120, 23)
# Count  3 :  (120, 23)
# Count  1 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  2 , Extracted user =  3 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (101, 23)
# Shape:  (307, 23)
# Count  2 :  (101, 23)
# Count  4 :  (101, 23)
# Count  1 :  (21, 23)
# Count  3 :  (21, 23)
# Count  5 :  (21, 23)
# Count  7 :  (21, 23)
# Count  8 :  (21, 23)
# Valid user =  2 , Extracted user =  4 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  2 :  (120, 23)
# Count  5 :  (120, 23)
# Count  1 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  2 , Extracted user =  5 accuracy =  0.9805555555555555
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  2 :  (120, 23)
# Count  7 :  (120, 23)
# Count  1 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  2 , Extracted user =  7 accuracy =  0.9027777777777778
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  2 :  (120, 23)
# Count  8 :  (120, 23)
# Count  1 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  2 , Extracted user =  8 accuracy =  0.9916666666666667
# --------------------------------------------------------------------------------
# Valid User:  3
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  3 :  (120, 23)
# Count  1 :  (120, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  3 , Extracted user =  1 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  3 :  (120, 23)
# Count  2 :  (120, 23)
# Count  1 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  3 , Extracted user =  2 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (101, 23)
# Shape:  (307, 23)
# Count  3 :  (101, 23)
# Count  4 :  (101, 23)
# Count  1 :  (21, 23)
# Count  2 :  (21, 23)
# Count  5 :  (21, 23)
# Count  7 :  (21, 23)
# Count  8 :  (21, 23)
# Valid user =  3 , Extracted user =  4 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  3 :  (120, 23)
# Count  5 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  7 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  3 , Extracted user =  5 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  3 :  (120, 23)
# Count  7 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  3 , Extracted user =  7 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  3 :  (120, 23)
# Count  8 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  3 , Extracted user =  8 accuracy =  1.0
# --------------------------------------------------------------------------------
# Valid User:  4
# --------------------------------------------------------------------------------
# True:  (24, 23)
# Shape:  (73, 23)
# Count  4 :  (24, 23)
# Count  1 :  (24, 23)
# Count  2 :  (5, 23)
# Count  3 :  (5, 23)
# Count  5 :  (5, 23)
# Count  7 :  (5, 23)
# Count  8 :  (5, 23)
# Valid user =  4 , Extracted user =  1 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (24, 23)
# Shape:  (73, 23)
# Count  4 :  (24, 23)
# Count  2 :  (24, 23)
# Count  1 :  (5, 23)
# Count  3 :  (5, 23)
# Count  5 :  (5, 23)
# Count  7 :  (5, 23)
# Count  8 :  (5, 23)
# Valid user =  4 , Extracted user =  2 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (24, 23)
# Shape:  (73, 23)
# Count  4 :  (24, 23)
# Count  3 :  (24, 23)
# Count  1 :  (5, 23)
# Count  2 :  (5, 23)
# Count  5 :  (5, 23)
# Count  7 :  (5, 23)
# Count  8 :  (5, 23)
# Valid user =  4 , Extracted user =  3 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (24, 23)
# Shape:  (73, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  1 :  (5, 23)
# Count  2 :  (5, 23)
# Count  3 :  (5, 23)
# Count  7 :  (5, 23)
# Count  8 :  (5, 23)
# Valid user =  4 , Extracted user =  5 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (24, 23)
# Shape:  (73, 23)
# Count  4 :  (24, 23)
# Count  7 :  (24, 23)
# Count  1 :  (5, 23)
# Count  2 :  (5, 23)
# Count  3 :  (5, 23)
# Count  5 :  (5, 23)
# Count  8 :  (5, 23)
# Valid user =  4 , Extracted user =  7 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (24, 23)
# Shape:  (73, 23)
# Count  4 :  (24, 23)
# Count  8 :  (24, 23)
# Count  1 :  (5, 23)
# Count  2 :  (5, 23)
# Count  3 :  (5, 23)
# Count  5 :  (5, 23)
# Count  7 :  (5, 23)
# Valid user =  4 , Extracted user =  8 accuracy =  1.0
# --------------------------------------------------------------------------------
# Valid User:  5
# --------------------------------------------------------------------------------
# True:  (97, 23)
# Shape:  (294, 23)
# Count  5 :  (97, 23)
# Count  1 :  (97, 23)
# Count  2 :  (20, 23)
# Count  3 :  (20, 23)
# Count  4 :  (20, 23)
# Count  7 :  (20, 23)
# Count  8 :  (20, 23)
# Valid user =  5 , Extracted user =  1 accuracy =  0.9863945578231292
# --------------------------------------------------------------------------------
# True:  (97, 23)
# Shape:  (294, 23)
# Count  5 :  (97, 23)
# Count  2 :  (97, 23)
# Count  1 :  (20, 23)
# Count  3 :  (20, 23)
# Count  4 :  (20, 23)
# Count  7 :  (20, 23)
# Count  8 :  (20, 23)
# Valid user =  5 , Extracted user =  2 accuracy =  0.9931972789115646
# --------------------------------------------------------------------------------
# True:  (97, 23)
# Shape:  (294, 23)
# Count  5 :  (97, 23)
# Count  3 :  (97, 23)
# Count  1 :  (20, 23)
# Count  2 :  (20, 23)
# Count  4 :  (20, 23)
# Count  7 :  (20, 23)
# Count  8 :  (20, 23)
# Valid user =  5 , Extracted user =  3 accuracy =  0.9965986394557823
# --------------------------------------------------------------------------------
# True:  (97, 23)
# Shape:  (294, 23)
# Count  5 :  (97, 23)
# Count  4 :  (97, 23)
# Count  1 :  (20, 23)
# Count  2 :  (20, 23)
# Count  3 :  (20, 23)
# Count  7 :  (20, 23)
# Count  8 :  (20, 23)
# Valid user =  5 , Extracted user =  4 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (97, 23)
# Shape:  (294, 23)
# Count  5 :  (97, 23)
# Count  7 :  (97, 23)
# Count  1 :  (20, 23)
# Count  2 :  (20, 23)
# Count  3 :  (20, 23)
# Count  4 :  (20, 23)
# Count  8 :  (20, 23)
# Valid user =  5 , Extracted user =  7 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (97, 23)
# Shape:  (294, 23)
# Count  5 :  (97, 23)
# Count  8 :  (97, 23)
# Count  1 :  (20, 23)
# Count  2 :  (20, 23)
# Count  3 :  (20, 23)
# Count  4 :  (20, 23)
# Count  7 :  (20, 23)
# Valid user =  5 , Extracted user =  8 accuracy =  0.9931972789115646
# --------------------------------------------------------------------------------
# Valid User:  7
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  7 :  (120, 23)
# Count  1 :  (120, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  7 , Extracted user =  1 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  7 :  (120, 23)
# Count  2 :  (120, 23)
# Count  1 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  7 , Extracted user =  2 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  7 :  (120, 23)
# Count  3 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  7 , Extracted user =  3 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (101, 23)
# Shape:  (307, 23)
# Count  7 :  (101, 23)
# Count  4 :  (101, 23)
# Count  1 :  (21, 23)
# Count  2 :  (21, 23)
# Count  3 :  (21, 23)
# Count  5 :  (21, 23)
# Count  8 :  (21, 23)
# Valid user =  7 , Extracted user =  4 accuracy =  0.7719869706840391
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  7 :  (120, 23)
# Count  5 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  8 :  (24, 23)
# Valid user =  7 , Extracted user =  5 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  7 :  (120, 23)
# Count  8 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Valid user =  7 , Extracted user =  8 accuracy =  1.0
# --------------------------------------------------------------------------------
# Valid User:  8
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  8 :  (120, 23)
# Count  1 :  (120, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  8 , Extracted user =  1 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  8 :  (120, 23)
# Count  2 :  (120, 23)
# Count  1 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  8 , Extracted user =  2 accuracy =  0.9861111111111112
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  8 :  (120, 23)
# Count  3 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  8 , Extracted user =  3 accuracy =  0.6666666666666666
# --------------------------------------------------------------------------------
# True:  (101, 23)
# Shape:  (307, 23)
# Count  8 :  (101, 23)
# Count  4 :  (101, 23)
# Count  1 :  (21, 23)
# Count  2 :  (21, 23)
# Count  3 :  (21, 23)
# Count  5 :  (21, 23)
# Count  7 :  (21, 23)
# Valid user =  8 , Extracted user =  4 accuracy =  1.0
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  8 :  (120, 23)
# Count  5 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  7 :  (24, 23)
# Valid user =  8 , Extracted user =  5 accuracy =  0.9972222222222222
# --------------------------------------------------------------------------------
# True:  (120, 23)
# Shape:  (360, 23)
# Count  8 :  (120, 23)
# Count  7 :  (120, 23)
# Count  1 :  (24, 23)
# Count  2 :  (24, 23)
# Count  3 :  (24, 23)
# Count  4 :  (24, 23)
# Count  5 :  (24, 23)
# Valid user =  8 , Extracted user =  7 accuracy =  1.0
# --------------------------------------------------------------------------------

# %% [markdown]
# ## RandomForestClassifier CV

# %%
n_estimators = 100
criterion = 'gini'
max_depth = None
min_samples_split = 2
min_samples_leaf = 1
max_features = 'auto'
n_jobs = -1
class_weight = 'balanced'

df['labels'] = df['user']

CV_RFC_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_.copy(), user)
    df_ = resample(df_)
    
    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)
    
    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]
    
    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))
    scoring = ('accuracy', 'balanced_accuracy')
    
    model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, \
                                   min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, \
                                   max_features=max_features, n_jobs=n_jobs, class_weight=class_weight)
    
    cv_results = cross_validate(model, X, y, scoring=scoring, cv=cv_split, n_jobs=-1)
    accuracy = cv_results['test_accuracy']
    
    CV_RFC_BIG_DICT[str(user)] = {}
    CV_RFC_BIG_DICT[str(user)]["accuracy"] = accuracy.copy()
    CV_RFC_BIG_DICT[str(user)]["mean_accuracy"] = np.mean(accuracy).copy()
    CV_RFC_BIG_DICT[str(user)]["max_accuracy"] = np.max(accuracy).copy()
    CV_RFC_BIG_DICT[str(user)]["min_accuracy"] = np.min(accuracy).copy()
    
    print("CV accuracy list: ", accuracy)
    print("CV mean accuracy: ", np.mean(accuracy))
    print("CV min accuracy: ", np.min(accuracy))
    print("CV max accuracy: ", np.max(accuracy))
    
    print("--------------------------------------------------------------------------------")
# Out:
# Valid User:  1
# --------------------------------------------------------------------------------
# CV accuracy list:  [0.97387117 1.         0.52112866 0.61796693 1.         1.        ]
# CV mean accuracy:  0.8521611277596328
# CV min accuracy:  0.5211286575305566
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  2
# --------------------------------------------------------------------------------
# CV accuracy list:  [0.96043638 1.         1.         1.         0.91073774 0.98010034]
# CV mean accuracy:  0.9752124089475515
# CV min accuracy:  0.9107377352772821
# CV max accuracy:  1.0
# --------------------------------------------------------------------------------
# Valid User:  3
# --------------------------------------------------------------------------------

# %% [markdown]
# ## RandomForestClassifier Final Validation

# %%
n_estimators = 100
criterion = 'gini'
max_depth = None
min_samples_split = 2
min_samples_leaf = 1
max_features = 'auto'
n_jobs = -1
class_weight = 'balanced'

df["labels"] = df["user"]

VALIDATION_RFC_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    VALIDATION_RFC_BIG_DICT[str(user)] = {}

    for ex_user in df.labels.unique():
        if ex_user != user:

            df_ = df.copy()

            df_for_test = []

            df__ = df_[df_.labels == ex_user].copy()
            df_for_test.append(df__)
            df_ = df_.drop(df__.index, axis=0)

            for user_ in df_.labels.unique():
                if user_ != ex_user:
                    test_size = int((0.25 * df_[df_.labels == user_].shape[0]) - 1)
                    df__ = df_[df_.labels == user_].sample(test_size).copy()
                    df_for_test.append(df__)
                    df_ = df_.drop(df__.index, axis=0)

            df_ = resample(df_.copy())
            df_ = split_users_into_two_classes(df_.copy(), user)
            df_ = resample(df_)

            df_ = df_.drop("labels", axis=1)

            dataset = df_.to_numpy().copy()
            np.random.shuffle(dataset)

            X = dataset[:, :-1]
            y = dataset[:, -1]

            model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, \
                                           min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, \
                                           max_features=max_features, n_jobs=n_jobs, class_weight=class_weight)
            model.fit(X, y)

            # Testing

            test_df = pd.concat(df_for_test)

            valid_user_in_test_count = test_df[test_df.labels == user].shape[0]
            ex_user_in_test_count = test_df[test_df.labels == ex_user].shape[0]
            others_in_test_count = [test_df[test_df.labels == x].shape[0] \
                                    for x in test_df.labels.unique() if x != user and x != ex_user]

            min_others_test_count = min(others_in_test_count)

            is_important_min = True
            if min_others_test_count <= ex_user_in_test_count and min_others_test_count <= valid_user_in_test_count:
                is_important_min = False

            new_df_parts = []
            if is_important_min is True:
                part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                other_sample_size = part_size // len(others_in_test_count) + 1

            else:
                part_size_can_be = min_others_test_count * len(others_in_test_count)
                        
                if part_size_can_be > min(valid_user_in_test_count, ex_user_in_test_count):
                    part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                    other_sample_size = part_size // len(others_in_test_count) + 1
                else:
                    part_size = part_size_can_be
                    other_sample_size = min_others_test_count
                    
            new_df_parts.append(test_df[test_df.labels == user].sample(part_size).copy())
            new_df_parts.append(test_df[test_df.labels == ex_user].sample(part_size).copy())

            for x in test_df.labels.unique():
                if x != user and x != ex_user:
                    new_df_parts.append(test_df[test_df.labels == x].sample(other_sample_size).copy())
                    
            test_df = pd.concat(new_df_parts)

            test_df.loc[test_df.labels != user, "user"] = 0
            test_df.loc[test_df.labels == user, "user"] = 1

            test_df = test_df.drop("labels", axis=1)

            test_dataset = test_df.to_numpy().copy()
            X_test = test_dataset[:, :-1].copy()
            y_test = test_dataset[:, -1].copy()

            VALIDATION_RFC_BIG_DICT[str(user)][ex_user] = {}
            VALIDATION_RFC_BIG_DICT[str(user)][ex_user]["y_test"] = y_test.copy()
            VALIDATION_RFC_BIG_DICT[str(user)][ex_user]["y_predict"] = model.predict(X_test).copy()
            VALIDATION_RFC_BIG_DICT[str(user)][ex_user]["y_proba"] = model.predict_proba(X_test).copy()

            print("Valid user = ", user, ", Extracted user = ", ex_user, "accuracy = ",
                    accuracy_score(VALIDATION_RFC_BIG_DICT[str(user)][ex_user]["y_test"], 
                                   VALIDATION_RFC_BIG_DICT[str(user)][ex_user]["y_predict"])
                 )

            print("--------------------------------------------------------------------------------")

# %% [markdown]
# ## SVC CV

# %%
C = 1
kernel = 'rbf'
degree = 1
gamma = 5

df['labels'] = df['user']

CV_SVC_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_.copy(), user)
    df_ = resample(df_)
    
    df_.loc[df_.user == 0, 'user'] = -1
    
    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)
    
    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]
    
    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))
    scoring = ('accuracy', 'balanced_accuracy')
    
    model = SVC(C=C, kernel=kernel, degree=degree, gamma=gamma)
    
    cv_results = cross_validate(model, X, y, scoring=scoring, cv=cv_split, n_jobs=-1)
    accuracy = cv_results['test_accuracy']
    
    CV_SVC_BIG_DICT[str(user)] = {}
    CV_SVC_BIG_DICT[str(user)]["accuracy"] = accuracy.copy()
    CV_SVC_BIG_DICT[str(user)]["mean_accuracy"] = np.mean(accuracy).copy()
    CV_SVC_BIG_DICT[str(user)]["max_accuracy"] = np.max(accuracy).copy()
    CV_SVC_BIG_DICT[str(user)]["min_accuracy"] = np.min(accuracy).copy()
    
    print("CV accuracy list: ", accuracy)
    print("CV mean accuracy: ", np.mean(accuracy))
    print("CV min accuracy: ", np.min(accuracy))
    print("CV max accuracy: ", np.max(accuracy))
    
    print("--------------------------------------------------------------------------------")

# %% [markdown]
# ## SVC Final Validation

# %%
C = 1
kernel = 'rbf'
degree = 1
gamma = 5

df["labels"] = df["user"]

VALIDATION_SVC_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    VALIDATION_SVC_BIG_DICT[str(user)] = {}

    for ex_user in df.labels.unique():
        if ex_user != user:

            df_ = df.copy()

            df_for_test = []

            df__ = df_[df_.labels == ex_user].copy()
            df_for_test.append(df__)
            df_ = df_.drop(df__.index, axis=0)

            for user_ in df_.labels.unique():
                if user_ != ex_user:
                    test_size = int((0.25 * df_[df_.labels == user_].shape[0]) - 1)
                    df__ = df_[df_.labels == user_].sample(test_size).copy()
                    df_for_test.append(df__)
                    df_ = df_.drop(df__.index, axis=0)

            df_ = resample(df_.copy())
            df_ = split_users_into_two_classes(df_.copy(), user)
            df_ = resample(df_)
            
            df_.loc[df_.user == 0, 'user'] = -1

            df_ = df_.drop("labels", axis=1)

            dataset = df_.to_numpy().copy()
            np.random.shuffle(dataset)

            X = dataset[:, :-1]
            y = dataset[:, -1]

            model = SVC(C=C, kernel=kernel, degree=degree, gamma=gamma)
            model.fit(X, y)

            # Testing

            test_df = pd.concat(df_for_test)

            valid_user_in_test_count = test_df[test_df.labels == user].shape[0]
            ex_user_in_test_count = test_df[test_df.labels == ex_user].shape[0]
            others_in_test_count = [test_df[test_df.labels == x].shape[0] \
                                    for x in test_df.labels.unique() if x != user and x != ex_user]

            min_others_test_count = min(others_in_test_count)

            is_important_min = True
            if min_others_test_count <= ex_user_in_test_count and min_others_test_count <= valid_user_in_test_count:
                is_important_min = False

            new_df_parts = []
            if is_important_min is True:
                part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                other_sample_size = part_size // len(others_in_test_count) + 1

            else:
                part_size_can_be = min_others_test_count * len(others_in_test_count)
                        
                if part_size_can_be > min(valid_user_in_test_count, ex_user_in_test_count):
                    part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                    other_sample_size = part_size // len(others_in_test_count) + 1
                else:
                    part_size = part_size_can_be
                    other_sample_size = min_others_test_count
                    
            new_df_parts.append(test_df[test_df.labels == user].sample(part_size).copy())
            new_df_parts.append(test_df[test_df.labels == ex_user].sample(part_size).copy())

            for x in test_df.labels.unique():
                if x != user and x != ex_user:
                    new_df_parts.append(test_df[test_df.labels == x].sample(other_sample_size).copy())
                    
            test_df = pd.concat(new_df_parts)

            test_df.loc[test_df.labels != user, "user"] = -1
            test_df.loc[test_df.labels == user, "user"] = 1

            test_df = test_df.drop("labels", axis=1)

            test_dataset = test_df.to_numpy().copy()
            X_test = test_dataset[:, :-1].copy()
            y_test = test_dataset[:, -1].copy()

            VALIDATION_SVC_BIG_DICT[str(user)][ex_user] = {}
            VALIDATION_SVC_BIG_DICT[str(user)][ex_user]["y_test"] = y_test.copy()
            VALIDATION_SVC_BIG_DICT[str(user)][ex_user]["y_predict"] = model.predict(X_test).copy()
            VALIDATION_SVC_BIG_DICT[str(user)][ex_user]["y_proba"] = model.decision_function(X_test).copy()

            print("Valid user = ", user, ", Extracted user = ", ex_user, "accuracy = ",
                    accuracy_score(VALIDATION_SVC_BIG_DICT[str(user)][ex_user]["y_test"], 
                                   VALIDATION_SVC_BIG_DICT[str(user)][ex_user]["y_predict"])
                 )

            print("--------------------------------------------------------------------------------")

# %% [markdown]
# ## LogReg CV

# %%
penalty = 'l2'
C = 0.01
solver = 'newton-cg'
max_iter = 1000
n_jobs = -1

df['labels'] = df['user']

CV_LR_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_.copy(), user)
    df_ = resample(df_)
    
    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)
    
    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]
    
    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))
    scoring = ('accuracy', 'balanced_accuracy')
    
    model = LogisticRegression(penalty=penalty, C=C, solver=solver, max_iter=max_iter, n_jobs=n_jobs)
    
    cv_results = cross_validate(model, X, y, scoring=scoring, cv=cv_split, n_jobs=-1)
    accuracy = cv_results['test_accuracy']
    
    CV_LR_BIG_DICT[str(user)] = {}
    CV_LR_BIG_DICT[str(user)]["accuracy"] = accuracy.copy()
    CV_LR_BIG_DICT[str(user)]["mean_accuracy"] = np.mean(accuracy).copy()
    CV_LR_BIG_DICT[str(user)]["max_accuracy"] = np.max(accuracy).copy()
    CV_LR_BIG_DICT[str(user)]["min_accuracy"] = np.min(accuracy).copy()
    
    print("CV accuracy list: ", accuracy)
    print("CV mean accuracy: ", np.mean(accuracy))
    print("CV min accuracy: ", np.min(accuracy))
    print("CV max accuracy: ", np.max(accuracy))
    
    print("--------------------------------------------------------------------------------")

# %% [markdown]
# ## LogReg Final Validation

# %%
penalty = 'l2'
C = 1
solver = 'newton-cg'
max_iter = 1000
n_jobs = -1

df["labels"] = df["user"]

VALIDATION_LR_BIG_DICT = {}

for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")
    
    VALIDATION_LR_BIG_DICT[str(user)] = {}

    for ex_user in df.labels.unique():
        if ex_user != user:

            df_ = df.copy()

            df_for_test = []

            df__ = df_[df_.labels == ex_user].copy()
            df_for_test.append(df__)
            df_ = df_.drop(df__.index, axis=0)

            for user_ in df_.labels.unique():
                if user_ != ex_user:
                    test_size = int((0.25 * df_[df_.labels == user_].shape[0]) - 1)
                    df__ = df_[df_.labels == user_].sample(test_size).copy()
                    df_for_test.append(df__)
                    df_ = df_.drop(df__.index, axis=0)

            df_ = resample(df_.copy())
            df_ = split_users_into_two_classes(df_.copy(), user)
            df_ = resample(df_)

            df_ = df_.drop("labels", axis=1)

            dataset = df_.to_numpy().copy()
            np.random.shuffle(dataset)

            X = dataset[:, :-1]
            y = dataset[:, -1]

            model = LogisticRegression(penalty=penalty, C=C, solver=solver, max_iter=max_iter, n_jobs=n_jobs)
            model.fit(X, y)

            # Testing

            test_df = pd.concat(df_for_test)

            valid_user_in_test_count = test_df[test_df.labels == user].shape[0]
            ex_user_in_test_count = test_df[test_df.labels == ex_user].shape[0]
            others_in_test_count = [test_df[test_df.labels == x].shape[0] \
                                    for x in test_df.labels.unique() if x != user and x != ex_user]

            min_others_test_count = min(others_in_test_count)

            is_important_min = True
            if min_others_test_count <= ex_user_in_test_count and min_others_test_count <= valid_user_in_test_count:
                is_important_min = False

            new_df_parts = []
            if is_important_min is True:
                part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                other_sample_size = part_size // len(others_in_test_count) + 1

            else:
                part_size_can_be = min_others_test_count * len(others_in_test_count)
                        
                if part_size_can_be > min(valid_user_in_test_count, ex_user_in_test_count):
                    part_size = min(valid_user_in_test_count, ex_user_in_test_count)
                    other_sample_size = part_size // len(others_in_test_count) + 1
                else:
                    part_size = part_size_can_be
                    other_sample_size = min_others_test_count
                    
            new_df_parts.append(test_df[test_df.labels == user].sample(part_size).copy())
            new_df_parts.append(test_df[test_df.labels == ex_user].sample(part_size).copy())

            for x in test_df.labels.unique():
                if x != user and x != ex_user:
                    new_df_parts.append(test_df[test_df.labels == x].sample(other_sample_size).copy())
                    
            test_df = pd.concat(new_df_parts)

            test_df.loc[test_df.labels != user, "user"] = 0
            test_df.loc[test_df.labels == user, "user"] = 1

            test_df = test_df.drop("labels", axis=1)

            test_dataset = test_df.to_numpy().copy()
            X_test = test_dataset[:, :-1].copy()
            y_test = test_dataset[:, -1].copy()

            VALIDATION_LR_BIG_DICT[str(user)][ex_user] = {}
            VALIDATION_LR_BIG_DICT[str(user)][ex_user]["y_test"] = y_test.copy()
            VALIDATION_LR_BIG_DICT[str(user)][ex_user]["y_predict"] = model.predict(X_test).copy()
            VALIDATION_LR_BIG_DICT[str(user)][ex_user]["y_proba"] = model.predict_proba(X_test).copy()

            print("Valid user = ", user, ", Extracted user = ", ex_user, "accuracy = ",
                    accuracy_score(VALIDATION_LR_BIG_DICT[str(user)][ex_user]["y_test"], 
                                   VALIDATION_LR_BIG_DICT[str(user)][ex_user]["y_predict"])
                 )

            print("--------------------------------------------------------------------------------")

# %%
for d in [CV_CATBOOST_BIG_DICT, CV_RFC_BIG_DICT, \
          CV_SVC_BIG_DICT, CV_LR_BIG_DICT]:
    
    for user, res in d.items():
        print("Valid User: ", user)
        print("--------------------------------------------------------------------------------")
        print('Mean accuracy: ', res['mean_accuracy'])

        print("--------------------------------------------------------------------------------")

# %%
for d in [VALIDATION_CATBOOST_BIG_DICT, VALIDATION_RFC_BIG_DICT, \
          VALIDATION_SVC_BIG_DICT, VALIDATION_LR_BIG_DICT]:
    
    for user, res in d.items():
        print("Valid User: ", user)
        print("--------------------------------------------------------------------------------")
        means_acc = []
        means_prec = []
        means_rec = []
        means_roc = []
        means_f1 = []
        
        for ex_user, ex_res in res.items():
            print('Ex user: ', ex_user)
            print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")

            y_true = ex_res['y_test']
            y_pred = ex_res['y_predict']
            if len(ex_res['y_proba'].shape) > 1 and ex_res['y_proba'].shape[1] > 1:
                y_proba = ex_res['y_proba'][:, 1]
            else:
                y_proba = ex_res['y_proba']
                
            acc = accuracy_score(y_true, y_pred)
            prec = precision_score(y_true, y_pred)
            rec = recall_score(y_true, y_pred)
            f1 = f1_score(y_true, y_pred)
            
            means_acc.append(acc)
            means_prec.append(prec)
            means_rec.append(rec)
            means_f1.append(f1)

            print('Accuracy: ', acc)
            print('Precision: ', prec)
            print('Recall: ', rec)
            try:
                roc = roc_auc_score(y_true, y_proba)
                means_roc.append(roc)
                print('ROC-AUC: ', roc)
            except Exception as e:
                print('ROC-AUC: skip')
            print('F1: ', f1)
            print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
            
        print('Mean accuracy: ', sum(means_acc) / len(means_acc))
        print('mean Precision: ', sum(means_prec) / len(means_prec))
        print('mean Recall: ', sum(means_rec) / len(means_rec))
        if len(means_roc) > 0:
            print('mean ROC-AUC: ', sum(means_roc) / len(means_roc))
        print('mean F1: ', sum(means_f1) / len(means_f1))

        print("--------------------------------------------------------------------------------")
