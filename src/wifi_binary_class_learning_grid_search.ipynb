# %%
from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, plot_roc_curve, make_scorer
from sklearn import preprocessing
from scipy import stats
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, LeaveOneGroupOut, PredefinedSplit, GridSearchCV
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
def make_dataframe_impl(df_count, rolling=True):
    dfs_list = []
    dfs_rows_len_list = []

    file_name = ""
    if rolling is True:
        file_name = ".\\_datasets\\600s\\wifi_rolling_dataset_"
    else:
        file_name = ".\\_datasets\\600s\\wifi_sampling_dataset_"

    for i in range(1, df_count + 1):
        df = pd.read_csv(file_name + str(i) + ".csv")
        df = df.drop(["timestamp"], axis=1)

        df = (df - df.min()) / (df.max() - df.min())

        df["user"] = i
        dfs_list.append(df)
        dfs_rows_len_list.append(df.shape[0])

    df = pd.concat(dfs_list, ignore_index=True)
    return df

# %%
def make_common_rolling_dataframe(df_count):
    return make_dataframe_impl(df_count, True)

def make_common_sampling_dataframe(df_count):
    return make_dataframe_impl(df_count, False)

# %%
def drop_bad_rows(df):
    bad_rows = set()
    for col in df.columns:
        if col != "user":
            for user in df.user.unique():
                for x in list(
                    df.loc[df.user == user, :][
                        np.abs(stats.zscore(df.loc[df.user == user, col])) > 3
                    ].index
                ):
                    bad_rows.add(x)

            for x in list(df[col][np.abs(stats.zscore(df[col])) > 3].index):
                bad_rows.add(x)

    df.drop(list(bad_rows), axis=0, inplace=True)

    return df

def drop_bad_cols(df):
    bad_cols = set()
    for col in df.columns:
        if col != "user":
            if df[df[col] != df[col].mean()].shape[0] < 0.1 * df.shape[0]:
                bad_cols.add(col)

            for user in df.user.unique():
                if (
                    df.loc[df.user == user, :][
                        df.loc[df.user == user, col]
                        != df.loc[df.user == user, col].mean()
                    ].shape[0]
                    < 0.1 * df.loc[df.user == user, :].shape[0]
                ):
                    bad_cols.add(col)

                elif (
                    np.sum(np.abs(stats.zscore(df.loc[df.user == user, col])) < 3)
                    < 0.9 * df.loc[df.user == user, col].shape[0]
                ):
                    bad_cols.add(col)

    df.drop(list(bad_cols), axis=1, inplace=True)

    return df

# %%
def resample(df):
    sampling_dfs = []
    need_count = 0

    for label, count in zip(df.user.value_counts().index, df.user.value_counts().values):
        if need_count == 0:
            need_count = count
            df_ = df[df.user == label]
            sampling_dfs.append(df_)
        else:
            df_ = df[df.user == label]
            df_over = df_.sample(need_count, replace=True, random_state=42)
            sampling_dfs.append(df_over)

    new_df = pd.concat(sampling_dfs)
    new_df = new_df.reset_index()

    return pd.concat(sampling_dfs)

def extract_delayed_user(df, user_label):
    df_user = df[df["user"] == user_label]
    df = df[df["user"] != user_label]
    return df_user, df

def split_users_into_two_classes(df, valid_user_label):
    df.loc[df["user"] != valid_user_label, "user"] = 0
    df.loc[df["user"] == valid_user_label, "user"] = 1
    return df

def get_cv_split(X, y, group_labels, valid_user_label):
    predefined_split_array = np.zeros(group_labels.shape[0])
    i = 0
    test_array = [x for x in range(group_labels.shape[0])]
    for test, _ in LeaveOneGroupOut().split(X, y, group_labels):
        diff = np.setdiff1d(test_array, test)
        if np.all(group_labels[diff[0] : diff[-1]] == valid_user_label) is np.bool_(True):
            for sample in diff:
                predefined_split_array[sample] = -1
        else:
            for sample in diff:
                predefined_split_array[sample] = i
            i += 1
    return predefined_split_array

# %%
df = make_common_rolling_dataframe(8)

# %%
df.columns.to_list()
# Out:
# ['level_mean',
#  'level_var',
#  'level_median',
#  'level_skew',
#  'level_kurt',
#  'count_mean',
#  'count_var',
#  'count_median',
#  'count_skew',
#  'count_kurt',
#  'conn_level_mean',
#  'conn_level_var',
#  'conn_level_median',
#  'conn_level_skew',
#  'conn_level_kurt',
#  'occured_nets_count_1_mean',
#  'occured_nets_count_1_var',
#  'occured_nets_count_1_median',
#  'occured_nets_count_1_skew',
#  'occured_nets_count_1_kurt',
#  'occured_nets_count_2_mean',
#  'occured_nets_count_2_mad',
#  'occured_nets_count_2_skew',
#  'occured_nets_count_3_mean',
#  'occured_nets_count_3_mad',
#  'occured_nets_count_3_skew',
#  'occured_nets_count_mean_mean',
#  'occured_nets_count_mean_mad',
#  'occured_nets_count_mean_skew',
#  'occured_nets_count_median_mean',
#  'occured_nets_count_median_mad',
#  'occured_nets_count_median_skew',
#  'occured_nets_count_var_mean',
#  'occured_nets_count_var_mad',
#  'occured_nets_count_var_skew',
#  'disappeared_nets_count_1_mean',
#  'disappeared_nets_count_1_mad',
#  'disappeared_nets_count_1_skew',
#  'disappeared_nets_count_2_mean',
#  'disappeared_nets_count_2_mad',
#  'disappeared_nets_count_2_skew',
#  'disappeared_nets_count_3_mean',
#  'disappeared_nets_count_3_mad',
#  'disappeared_nets_count_3_skew',
#  'disappeared_nets_count_mean_mean',
#  'disappeared_nets_count_mean_mad',
#  'disappeared_nets_count_mean_skew',
#  'disappeared_nets_count_median_mean',
#  'disappeared_nets_count_median_mad',
#  'disappeared_nets_count_median_skew',
#  'disappeared_nets_count_var_mean',
#  'disappeared_nets_count_var_mad',
#  'disappeared_nets_count_var_skew',
#  'jaccard_index_1_mean',
#  'jaccard_index_1_mad',
#  'jaccard_index_1_skew',
#  'jaccard_index_2_mean',
#  'jaccard_index_2_mad',
#  'jaccard_index_2_skew',
#  'jaccard_index_3_mean',
#  'jaccard_index_3_mad',
#  'jaccard_index_3_skew',
#  'jaccard_index_mean_mean',
#  'jaccard_index_mean_mad',
#  'jaccard_index_mean_skew',
#  'jaccard_index_median_mean',
#  'jaccard_index_median_mad',
#  'jaccard_index_median_skew',
#  'jaccard_index_var_mean',
#  'jaccard_index_var_mad',
#  'jaccard_index_var_skew',
#  'occur_speed_1_mean',
#  'occur_speed_1_mad',
#  'occur_speed_1_skew',
#  'occur_speed_2_mean',
#  'occur_speed_2_mad',
#  'occur_speed_2_skew',
#  'occur_speed_3_mean',
#  'occur_speed_3_mad',
#  'occur_speed_3_skew',
#  'occur_speed_mean_mean',
#  'occur_speed_mean_mad',
#  'occur_speed_mean_skew',
#  'occur_speed_median_mean',
#  'occur_speed_median_mad',
#  'occur_speed_median_skew',
#  'occur_speed_var_mean',
#  'occur_speed_var_mad',
#  'occur_speed_var_skew',
#  'level_speed_1_mean',
#  'level_speed_1_mad',
#  'level_speed_1_skew',
#  'level_speed_2_mean',
#  'level_speed_2_mad',
#  'level_speed_2_skew',
#  'level_speed_3_mean',
#  'level_speed_3_mad',
#  'level_speed_3_skew',
#  'level_speed_mean_mean',
#  'level_speed_mean_mad',
#  'level_speed_mean_skew',
#  'level_speed_median_mean',
#  'level_speed_median_mad',
#  'level_speed_median_skew',
#  'level_speed_var_mean',
#  'level_speed_var_mad',
#  'level_speed_var_skew',
#  'conn_level_speed_1_mean',
#  'conn_level_speed_1_mad',
#  'conn_level_speed_1_skew',
#  'conn_level_speed_2_mean',
#  'conn_level_speed_2_mad',
#  'conn_level_speed_2_skew',
#  'conn_level_speed_3_mean',
#  'conn_level_speed_3_mad',
#  'conn_level_speed_3_skew',
#  'conn_level_speed_mean_mean',
#  'conn_level_speed_mean_mad',
#  'conn_level_speed_mean_skew',
#  'conn_level_speed_median_mean',
#  'conn_level_speed_median_mad',
#  'conn_level_speed_median_skew',
#  'conn_level_speed_var_mean',
#  'conn_level_speed_var_mad',
#  'conn_level_speed_var_skew',
#  'count_speed_1_mean',
#  'count_speed_1_mad',
#  'count_speed_1_skew',
#  'count_speed_2_mean',
#  'count_speed_2_mad',
#  'count_speed_2_skew',
#  'count_speed_3_mean',
#  'count_speed_3_mad',
#  'count_speed_3_skew',
#  'count_speed_mean_mean',
#  'count_speed_mean_mad',
#  'count_speed_mean_skew',
#  'count_speed_median_mean',
#  'count_speed_median_mad',
#  'count_speed_median_skew',
#  'count_speed_var_mean',
#  'count_speed_var_mad',
#  'count_speed_var_skew',
#  'acceleration_occured_nets_count_mean_1_mean',
#  'acceleration_occured_nets_count_mean_1_mad',
#  'acceleration_occured_nets_count_mean_1_skew',
#  'acceleration_occured_nets_count_mean_2_mean',
#  'acceleration_occured_nets_count_mean_2_mad',
#  'acceleration_occured_nets_count_mean_2_skew',
#  'acceleration_occured_nets_count_mean_3_mean',
#  'acceleration_occured_nets_count_mean_3_mad',
#  'acceleration_occured_nets_count_mean_3_skew',
#  'acceleration_occured_nets_count_mean_mean_mean',
#  'acceleration_occured_nets_count_mean_mean_mad',
#  'acceleration_occured_nets_count_mean_mean_skew',
#  'acceleration_occured_nets_count_mean_median_mean',
#  'acceleration_occured_nets_count_mean_median_mad',
#  'acceleration_occured_nets_count_mean_median_skew',
#  'acceleration_occured_nets_count_mean_var_mean',
#  'acceleration_occured_nets_count_mean_var_mad',
#  'acceleration_occured_nets_count_mean_var_skew',
#  'acceleration_jaccard_index_mean_1_mean',
#  'acceleration_jaccard_index_mean_1_mad',
#  'acceleration_jaccard_index_mean_1_skew',
#  'acceleration_jaccard_index_mean_2_mean',
#  'acceleration_jaccard_index_mean_2_mad',
#  'acceleration_jaccard_index_mean_2_skew',
#  'acceleration_jaccard_index_mean_3_mean',
#  'acceleration_jaccard_index_mean_3_mad',
#  'acceleration_jaccard_index_mean_3_skew',
#  'acceleration_jaccard_index_mean_mean_mean',
#  'acceleration_jaccard_index_mean_mean_mad',
#  'acceleration_jaccard_index_mean_mean_skew',
#  'acceleration_jaccard_index_mean_median_mean',
#  'acceleration_jaccard_index_mean_median_mad',
#  'acceleration_jaccard_index_mean_median_skew',
#  'acceleration_jaccard_index_mean_var_mean',
#  'acceleration_jaccard_index_mean_var_mad',
#  'acceleration_jaccard_index_mean_var_skew',
#  'acceleration_occur_speed_mean_1_mean',
#  'acceleration_occur_speed_mean_1_mad',
#  'acceleration_occur_speed_mean_1_skew',
#  'acceleration_occur_speed_mean_2_mean',
#  'acceleration_occur_speed_mean_2_mad',
#  'acceleration_occur_speed_mean_2_skew',
#  'acceleration_occur_speed_mean_3_mean',
#  'acceleration_occur_speed_mean_3_mad',
#  'acceleration_occur_speed_mean_3_skew',
#  'acceleration_occur_speed_mean_mean_mean',
#  'acceleration_occur_speed_mean_mean_mad',
#  'acceleration_occur_speed_mean_mean_skew',
#  'acceleration_occur_speed_mean_median_mean',
#  'acceleration_occur_speed_mean_median_mad',
#  'acceleration_occur_speed_mean_median_skew',
#  'acceleration_occur_speed_mean_var_mean',
#  'acceleration_occur_speed_mean_var_mad',
#  'acceleration_occur_speed_mean_var_skew',
#  'acceleration_disappeared_nets_count_mean_1_mean',
#  'acceleration_disappeared_nets_count_mean_1_mad',
#  'acceleration_disappeared_nets_count_mean_1_skew',
#  'acceleration_disappeared_nets_count_mean_2_mean',
#  'acceleration_disappeared_nets_count_mean_2_mad',
#  'acceleration_disappeared_nets_count_mean_2_skew',
#  'acceleration_disappeared_nets_count_mean_3_mean',
#  'acceleration_disappeared_nets_count_mean_3_mad',
#  'acceleration_disappeared_nets_count_mean_3_skew',
#  'acceleration_disappeared_nets_count_mean_mean_mean',
#  'acceleration_disappeared_nets_count_mean_mean_mad',
#  'acceleration_disappeared_nets_count_mean_mean_skew',
#  'acceleration_disappeared_nets_count_mean_median_mean',
#  'acceleration_disappeared_nets_count_mean_median_mad',
#  'acceleration_disappeared_nets_count_mean_median_skew',
#  'acceleration_disappeared_nets_count_mean_var_mean',
#  'acceleration_disappeared_nets_count_mean_var_mad',
#  'acceleration_disappeared_nets_count_mean_var_skew',
#  'acceleration_conn_level_speed_mean_1_mean',
#  'acceleration_conn_level_speed_mean_1_mad',
#  'acceleration_conn_level_speed_mean_1_skew',
#  'acceleration_conn_level_speed_mean_2_mean',
#  'acceleration_conn_level_speed_mean_2_mad',
#  'acceleration_conn_level_speed_mean_2_skew',
#  'acceleration_conn_level_speed_mean_3_mean',
#  'acceleration_conn_level_speed_mean_3_mad',
#  'acceleration_conn_level_speed_mean_3_skew',
#  'acceleration_conn_level_speed_mean_mean_mean',
#  'acceleration_conn_level_speed_mean_mean_mad',
#  'acceleration_conn_level_speed_mean_mean_skew',
#  'acceleration_conn_level_speed_mean_median_mean',
#  'acceleration_conn_level_speed_mean_median_mad',
#  'acceleration_conn_level_speed_mean_median_skew',
#  'acceleration_conn_level_speed_mean_var_mean',
#  'acceleration_conn_level_speed_mean_var_mad',
#  'acceleration_conn_level_speed_mean_var_skew',
#  'acceleration_count_speed_mean_1_mean',
#  'acceleration_count_speed_mean_1_mad',
#  'acceleration_count_speed_mean_1_skew',
#  'acceleration_count_speed_mean_2_mean',
#  'acceleration_count_speed_mean_2_mad',
#  'acceleration_count_speed_mean_2_skew',
#  'acceleration_count_speed_mean_3_mean',
#  'acceleration_count_speed_mean_3_mad',
#  'acceleration_count_speed_mean_3_skew',
#  'acceleration_count_speed_mean_mean_mean',
#  'acceleration_count_speed_mean_mean_mad',
#  'acceleration_count_speed_mean_mean_skew',
#  'acceleration_count_speed_mean_median_mean',
#  'acceleration_count_speed_mean_median_mad',
#  'acceleration_count_speed_mean_median_skew',
#  'acceleration_count_speed_mean_var_mean',
#  'acceleration_count_speed_mean_var_mad',
#  'acceleration_count_speed_mean_var_skew',
#  'user']

# %%
features = ['level_mean',
 'level_var',
 'level_median',
 'level_skew',
 'level_kurt',
 'count_mean',
 'count_var',
 'count_median',
 'count_skew',
 'count_kurt',
 'conn_level_mean',
 'conn_level_var',
 'conn_level_median',
 'conn_level_skew',
 'conn_level_kurt',
#  'occured_nets_count_1_mean',
#  'occured_nets_count_1_var',
#  'occured_nets_count_1_median',
#  'occured_nets_count_1_skew',
#  'occured_nets_count_1_kurt',
#  'occured_nets_count_2_mean',
#  'occured_nets_count_2_mad',
#  'occured_nets_count_2_skew',
#  'occured_nets_count_3_mean',
#  'occured_nets_count_3_mad',
#  'occured_nets_count_3_skew',
 'occured_nets_count_mean_mean',
 'occured_nets_count_mean_mad',
 'occured_nets_count_mean_skew',
 'occured_nets_count_median_mean',
 'occured_nets_count_median_mad',
 'occured_nets_count_median_skew',
 'occured_nets_count_var_mean',
 'occured_nets_count_var_mad',
 'occured_nets_count_var_skew',
#  'disappeared_nets_count_1_mean',
#  'disappeared_nets_count_1_mad',
#  'disappeared_nets_count_1_skew',
#  'disappeared_nets_count_2_mean',
#  'disappeared_nets_count_2_mad',
#  'disappeared_nets_count_2_skew',
#  'disappeared_nets_count_3_mean',
#  'disappeared_nets_count_3_mad',
#  'disappeared_nets_count_3_skew',
 'disappeared_nets_count_mean_mean',
 'disappeared_nets_count_mean_mad',
 'disappeared_nets_count_mean_skew',
 'disappeared_nets_count_median_mean',
 'disappeared_nets_count_median_mad',
 'disappeared_nets_count_median_skew',
 'disappeared_nets_count_var_mean',
 'disappeared_nets_count_var_mad',
 'disappeared_nets_count_var_skew',
#  'jaccard_index_1_mean',
#  'jaccard_index_1_mad',
#  'jaccard_index_1_skew',
#  'jaccard_index_2_mean',
#  'jaccard_index_2_mad',
#  'jaccard_index_2_skew',
#  'jaccard_index_3_mean',
#  'jaccard_index_3_mad',
#  'jaccard_index_3_skew',
 'jaccard_index_mean_mean',
 'jaccard_index_mean_mad',
 'jaccard_index_mean_skew',
 'jaccard_index_median_mean',
 'jaccard_index_median_mad',
 'jaccard_index_median_skew',
 'jaccard_index_var_mean',
 'jaccard_index_var_mad',
 'jaccard_index_var_skew',
#  'occur_speed_1_mean',
#  'occur_speed_1_mad',
#  'occur_speed_1_skew',
#  'occur_speed_2_mean',
#  'occur_speed_2_mad',
#  'occur_speed_2_skew',
#  'occur_speed_3_mean',
#  'occur_speed_3_mad',
#  'occur_speed_3_skew',
 'occur_speed_mean_mean',
 'occur_speed_mean_mad',
 'occur_speed_mean_skew',
 'occur_speed_median_mean',
 'occur_speed_median_mad',
 'occur_speed_median_skew',
 'occur_speed_var_mean',
 'occur_speed_var_mad',
 'occur_speed_var_skew',
#  'level_speed_1_mean',
#  'level_speed_1_mad',
#  'level_speed_1_skew',
#  'level_speed_2_mean',
#  'level_speed_2_mad',
#  'level_speed_2_skew',
#  'level_speed_3_mean',
#  'level_speed_3_mad',
#  'level_speed_3_skew',
 'level_speed_mean_mean',
 'level_speed_mean_mad',
 'level_speed_mean_skew',
 'level_speed_median_mean',
 'level_speed_median_mad',
 'level_speed_median_skew',
 'level_speed_var_mean',
 'level_speed_var_mad',
 'level_speed_var_skew',
#  'conn_level_speed_1_mean',
#  'conn_level_speed_1_mad',
#  'conn_level_speed_1_skew',
#  'conn_level_speed_2_mean',
#  'conn_level_speed_2_mad',
#  'conn_level_speed_2_skew',
#  'conn_level_speed_3_mean',
#  'conn_level_speed_3_mad',
#  'conn_level_speed_3_skew',
 'conn_level_speed_mean_mean',
 'conn_level_speed_mean_mad',
 'conn_level_speed_mean_skew',
 'conn_level_speed_median_mean',
 'conn_level_speed_median_mad',
 'conn_level_speed_median_skew',
 'conn_level_speed_var_mean',
 'conn_level_speed_var_mad',
 'conn_level_speed_var_skew',
#  'count_speed_1_mean',
#  'count_speed_1_mad',
#  'count_speed_1_skew',
#  'count_speed_2_mean',
#  'count_speed_2_mad',
#  'count_speed_2_skew',
#  'count_speed_3_mean',
#  'count_speed_3_mad',
#  'count_speed_3_skew',
 'count_speed_mean_mean',
 'count_speed_mean_mad',
 'count_speed_mean_skew',
 'count_speed_median_mean',
 'count_speed_median_mad',
 'count_speed_median_skew',
 'count_speed_var_mean',
 'count_speed_var_mad',
 'count_speed_var_skew',
#  'acceleration_occured_nets_count_mean_1_mean',
#  'acceleration_occured_nets_count_mean_1_mad',
#  'acceleration_occured_nets_count_mean_1_skew',
#  'acceleration_occured_nets_count_mean_2_mean',
#  'acceleration_occured_nets_count_mean_2_mad',
#  'acceleration_occured_nets_count_mean_2_skew',
#  'acceleration_occured_nets_count_mean_3_mean',
#  'acceleration_occured_nets_count_mean_3_mad',
#  'acceleration_occured_nets_count_mean_3_skew',
#  'acceleration_occured_nets_count_mean_mean_mean',
#  'acceleration_occured_nets_count_mean_mean_mad',
#  'acceleration_occured_nets_count_mean_mean_skew',
#  'acceleration_occured_nets_count_mean_median_mean',
#  'acceleration_occured_nets_count_mean_median_mad',
#  'acceleration_occured_nets_count_mean_median_skew',
#  'acceleration_occured_nets_count_mean_var_mean',
#  'acceleration_occured_nets_count_mean_var_mad',
#  'acceleration_occured_nets_count_mean_var_skew',
#  'acceleration_jaccard_index_mean_1_mean',
#  'acceleration_jaccard_index_mean_1_mad',
#  'acceleration_jaccard_index_mean_1_skew',
#  'acceleration_jaccard_index_mean_2_mean',
#  'acceleration_jaccard_index_mean_2_mad',
#  'acceleration_jaccard_index_mean_2_skew',
#  'acceleration_jaccard_index_mean_3_mean',
#  'acceleration_jaccard_index_mean_3_mad',
#  'acceleration_jaccard_index_mean_3_skew',
#  'acceleration_jaccard_index_mean_mean_mean',
#  'acceleration_jaccard_index_mean_mean_mad',
#  'acceleration_jaccard_index_mean_mean_skew',
#  'acceleration_jaccard_index_mean_median_mean',
#  'acceleration_jaccard_index_mean_median_mad',
#  'acceleration_jaccard_index_mean_median_skew',
#  'acceleration_jaccard_index_mean_var_mean',
#  'acceleration_jaccard_index_mean_var_mad',
#  'acceleration_jaccard_index_mean_var_skew',
#  'acceleration_occur_speed_mean_1_mean',
#  'acceleration_occur_speed_mean_1_mad',
#  'acceleration_occur_speed_mean_1_skew',
#  'acceleration_occur_speed_mean_2_mean',
#  'acceleration_occur_speed_mean_2_mad',
#  'acceleration_occur_speed_mean_2_skew',
#  'acceleration_occur_speed_mean_3_mean',
#  'acceleration_occur_speed_mean_3_mad',
#  'acceleration_occur_speed_mean_3_skew',
#  'acceleration_occur_speed_mean_mean_mean',
#  'acceleration_occur_speed_mean_mean_mad',
#  'acceleration_occur_speed_mean_mean_skew',
#  'acceleration_occur_speed_mean_median_mean',
#  'acceleration_occur_speed_mean_median_mad',
#  'acceleration_occur_speed_mean_median_skew',
#  'acceleration_occur_speed_mean_var_mean',
#  'acceleration_occur_speed_mean_var_mad',
#  'acceleration_occur_speed_mean_var_skew',
#  'acceleration_disappeared_nets_count_mean_1_mean',
#  'acceleration_disappeared_nets_count_mean_1_mad',
#  'acceleration_disappeared_nets_count_mean_1_skew',
#  'acceleration_disappeared_nets_count_mean_2_mean',
#  'acceleration_disappeared_nets_count_mean_2_mad',
#  'acceleration_disappeared_nets_count_mean_2_skew',
#  'acceleration_disappeared_nets_count_mean_3_mean',
#  'acceleration_disappeared_nets_count_mean_3_mad',
#  'acceleration_disappeared_nets_count_mean_3_skew',
#  'acceleration_disappeared_nets_count_mean_mean_mean',
#  'acceleration_disappeared_nets_count_mean_mean_mad',
#  'acceleration_disappeared_nets_count_mean_mean_skew',
#  'acceleration_disappeared_nets_count_mean_median_mean',
#  'acceleration_disappeared_nets_count_mean_median_mad',
#  'acceleration_disappeared_nets_count_mean_median_skew',
#  'acceleration_disappeared_nets_count_mean_var_mean',
#  'acceleration_disappeared_nets_count_mean_var_mad',
#  'acceleration_disappeared_nets_count_mean_var_skew',
#  'acceleration_conn_level_speed_mean_1_mean',
#  'acceleration_conn_level_speed_mean_1_mad',
#  'acceleration_conn_level_speed_mean_1_skew',
#  'acceleration_conn_level_speed_mean_2_mean',
#  'acceleration_conn_level_speed_mean_2_mad',
#  'acceleration_conn_level_speed_mean_2_skew',
#  'acceleration_conn_level_speed_mean_3_mean',
#  'acceleration_conn_level_speed_mean_3_mad',
#  'acceleration_conn_level_speed_mean_3_skew',
#  'acceleration_conn_level_speed_mean_mean_mean',
#  'acceleration_conn_level_speed_mean_mean_mad',
#  'acceleration_conn_level_speed_mean_mean_skew',
#  'acceleration_conn_level_speed_mean_median_mean',
#  'acceleration_conn_level_speed_mean_median_mad',
#  'acceleration_conn_level_speed_mean_median_skew',
#  'acceleration_conn_level_speed_mean_var_mean',
#  'acceleration_conn_level_speed_mean_var_mad',
#  'acceleration_conn_level_speed_mean_var_skew',
#  'acceleration_count_speed_mean_1_mean',
#  'acceleration_count_speed_mean_1_mad',
#  'acceleration_count_speed_mean_1_skew',
#  'acceleration_count_speed_mean_2_mean',
#  'acceleration_count_speed_mean_2_mad',
#  'acceleration_count_speed_mean_2_skew',
#  'acceleration_count_speed_mean_3_mean',
#  'acceleration_count_speed_mean_3_mad',
#  'acceleration_count_speed_mean_3_skew',
#  'acceleration_count_speed_mean_mean_mean',
#  'acceleration_count_speed_mean_mean_mad',
#  'acceleration_count_speed_mean_mean_skew',
#  'acceleration_count_speed_mean_median_mean',
#  'acceleration_count_speed_mean_median_mad',
#  'acceleration_count_speed_mean_median_skew',
#  'acceleration_count_speed_mean_var_mean',
#  'acceleration_count_speed_mean_var_mad',
#  'acceleration_count_speed_mean_var_skew',
 'user' ]

# %%
df = df.drop(df.columns.difference(features), axis=1)
df = df.dropna(how='all')
df = df.fillna(0)

# %%
df = drop_bad_cols(df)
df = drop_bad_rows(df)

# %%
corr_matrix = df.corr().abs()
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
corr_cols = [column for column in upper_tri.columns if any(abs(upper_tri[column]) > 0.7) and column != "user"]
df = df.drop(corr_cols, axis=1)

# %%
df['labels'] = df['user']

# %%
gs_df_parts = []
for user in df.labels.unique():
    new_df = df[df.labels == user].sample(int(df[df.labels == user].shape[0] * 0.2)).copy()
    gs_df_parts.append(new_df)

df = pd.concat(gs_df_parts)

# %% [markdown]
# ## CatBoostClassifier GridSearchCV

# %%
for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")

    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_, user)
    df_ = resample(df_)

    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)

    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]

    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))

    clf = CatBoostClassifier()
    params = {'iterations': [100, 500],
              'depth': [6, 10],
              'loss_function': ['Logloss', 'CrossEntropy'],
              'l2_leaf_reg': [1, 10, 100],
              'leaf_estimation_iterations': [2, 5, 10],
              'logging_level':['Silent']
              }

    scorer = make_scorer(accuracy_score)
    clf_grid = GridSearchCV(estimator=clf, param_grid=params, scoring=scorer, cv=cv_split)

    clf_grid.fit(X, y)

    best_params = clf_grid.best_params_
    print('Best params: ', best_params)

    print("--------------------------------------------------------------------------------")
# Out:
# Valid User:  1
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-85b4e758df99> in <module>
#      28     clf_grid = GridSearchCV(estimator=clf, param_grid=params, scoring=scorer, cv=cv_split)
#      29
# ---> 30     clf_grid.fit(X, y)
#      31
#      32     best_params = clf_grid.best_params_
#
# D:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# D:\Program Files\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# D:\Program Files\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# D:\Program Files\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\Program Files\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\Program Files\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# D:\Program Files\Anaconda3\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4300         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4301                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 4302                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4303         return self
#    4304
#
# D:\Program Files\Anaconda3\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1795             use_best_model, eval_set, verbose, logging_level, plot,
#    1796             column_description, verbose_eval, metric_period, silent, early_stopping_rounds,
# -> 1797             save_snapshot, snapshot_file, snapshot_interval, init_model
#    1798         )
#    1799         params = train_params["params"]
#
# D:\Program Files\Anaconda3\lib\site-packages\catboost\core.py in _prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1682         train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#    1683                                        sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
# -> 1684                                        baseline, column_description)
#    1685         if train_pool.is_empty_:
#    1686             raise CatBoostError("X is empty.")
#
# D:\Program Files\Anaconda3\lib\site-packages\catboost\core.py in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#     983             raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
#     984         train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
# --> 985                           group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#     986     return train_pool
#     987
#
# D:\Program Files\Anaconda3\lib\site-packages\catboost\core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     453                     )
#     454
# --> 455                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     456         super(Pool, self).__init__()
#     457
#
# KeyboardInterrupt:

# %% [markdown]
# ## RandomForestClassifier GridSearchCV

# %%
for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")

    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_, user)
    df_ = resample(df_)

    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)

    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]

    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))

    clf = RandomForestClassifier()
    params = {'n_estimators': [50, 100],
              'criterion': ['gini', 'entropy'],
              'max_depth': [10, 100, None],
              'min_samples_split': [2, 100],
              'min_samples_leaf': [1, 10, 100],
              'max_features':['auto', 'sqrt', 'log2'],
              'n_jobs': [-1],
              'class_weight': ['balanced']
             }

    scorer = make_scorer(accuracy_score)
    clf_grid = GridSearchCV(estimator=clf, param_grid=params, scoring=scorer, cv=cv_split)

    clf_grid.fit(X, y)

    best_params = clf_grid.best_params_
    print('Best params: ', best_params)

    print("--------------------------------------------------------------------------------")

# %% [markdown]
# ## SVC GridSearchCV

# %%
for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")

    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_, user)
    df_ = resample(df_)
    
    df_.loc[df_.user == 0, 'user'] = -1

    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)

    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]

    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))

    clf = SVC()
    params = {'C': [0.01, 1, 10, 100],
              'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
              'degree': [1, 2, 3, 4],
              'gamma': ['scale', 'auto', 0.01, 0.1, 1, 3, 5],
              'cache_size': [2000],
              'max_iter':[-1, 100, 1000]
             }

    scorer = make_scorer(accuracy_score)
    clf_grid = GridSearchCV(estimator=clf, param_grid=params, scoring=scorer, cv=cv_split)

    clf_grid.fit(X, y)

    best_params = clf_grid.best_params_
    print('Best params: ', best_params)

    print("--------------------------------------------------------------------------------")

# %% [markdown]
# ## LogReg GridSearchCV

# %%
for user in df.labels.unique():
    print("Valid User: ", user)
    print("--------------------------------------------------------------------------------")

    df_ = resample(df.copy())
    df_ = split_users_into_two_classes(df_, user)
    df_ = resample(df_)

    group_labels = df_.labels.to_numpy().copy()
    df_ = df_.drop('labels', axis=1)

    dataset = df_.to_numpy().copy()
    X = dataset[:, :-1]
    y = dataset[:, -1]

    cv_split = PredefinedSplit(test_fold=get_cv_split(X, y, group_labels, user))

    clf = LogisticRegression()
    params = {'penalty': ['l2', 'elasticnet'],
              'C': [0.01, 1, 100],
              'solver': ['newton-cg', 'lbfgs', 'sag', 'saga'],
              'max_iter': [500, 1000, 10000],
              'n_jobs': [-1]
             }

    scorer = make_scorer(accuracy_score)
    clf_grid = GridSearchCV(estimator=clf, param_grid=params, scoring=scorer, cv=cv_split)

    clf_grid.fit(X, y)

    best_params = clf_grid.best_params_
    print('Best params: ', best_params)

    print("--------------------------------------------------------------------------------")
